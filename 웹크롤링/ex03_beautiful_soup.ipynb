# %% [markdown]
# # beautifulsoup4 라이브러리
# - http 통신으로 받아온 text 형식의 html 문서를 DOM 형식으로 파싱한다.
# - text를 html로 바꾼다.
# - dom tree 검색이 가능, node 검색이 가능!!
# - pip install beautifulsoup4
# - (mac)만약 오류 -> sudo python3 -m pip install bs4

# %% [markdown]
# 다나와
#
# #danawa_menubar .link_nav
#
# 부모 -> id를 가진 것 ->
#
# #danawa_menubar .link_nav:nth-child(8)  n번째에 있는 것
# #danawa_menubar>.main-header__nav> .link_nav:nth-child(8)  # 더 정확하게 하려면 이렇게
#
#
# id 선택자는?

# %%
import requests as req # as : 모듈 전체에 가짜 이름
from bs4 import BeautifulSoup as bs # from import : 특정 함수 모듈을 가져오는 방법

url="https://www.danawa.com"
header={'User-Agent': 'Mozilla/5.0'} 
res = req.get(url=url, headers=header)
print(res.text)

res.text
# Out:
# <!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko">
# <head>
# <title>스마트한 쇼핑검색, 다나와! : 가격비교 사이트</title>
# <meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=Edge" /><meta name="Title" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" /><meta name="Description" content="온라인 쇼핑몰, 오픈마켓, 소셜커머스, 백화점, 전문몰 등 전 상품 정보 가격비교 사이트, 비교하면 다나와" /><meta name="Keywords" content="가격비교, 상품 추천, 가격비교사이트, 다나와, 가격비교 사이트, 가격비교 싸이트, 가격 검색, 최저가, 추천, 인터넷쇼핑, 온라인쇼핑, 쇼핑, 쇼핑몰, 싸게 파는 곳, 지식쇼핑" /><meta name="Subject" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트">
# <meta name="author" content="https://www.danawa.com">
# <meta name="robots" content="index, follow">
# <meta property="og:title" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" />
# <meta property="og:url" content="https://www.danawa.com" />
# <meta property="og:type" content="website"/>
# <meta property="og:description" content="온라인 쇼핑몰, 오픈마켓, 소셜커머스, 백화점, 전문몰 등 전 상품 정보 가격비교 사이트, 비교하면 다나와"/>
# <meta property="og:site_name" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" />
# <meta property="og:image" content="https://img.danawa.com/new/tour/img/logo/sns_danawa.jpg"/>
# <meta name="google-site-verification" content="Zd_kQLEjiNKsk4p5LtRWR2AZFpJf5XlwGsmhy3iAukc"/>
# <meta name="naver-site-verification" content="4379d7b598f27c5fef523e358a8390cdc785ce0f"/>
# <link rel="alternate" href="https://m.danawa.com/">
# <link rel="canonical" href="https://www.danawa.com/">
# <meta content="width=1200" name="viewport" />
# <link rel="shortcut icon" href="//img.danawa.com/new/danawa_main/v1/img/danawa_favicon.ico" />
# <link rel="stylesheet" type="text/css" href="//static.danawa.com/css/prod.main.v1.css?v=2405311423"/>
# <link rel="stylesheet" type="text/css" href="//static.danawa.com/globaljs/external/swiper/5.4.5/swiper.min.css?v=2405311423"/>
# <link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/wish_pop.css?v=2405311423"/>
# <script src="//static.danawa.com/globaljs/external/jquery/core/1.11.0/jquery-1.11.0.min.js?v=2406251119"></script>
# <script charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/gnb_ui.js?v=2406251119"></script>
# <script charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/jquery.addProductToWishList.js?v=2406251119"></script>
# <script src="//static.danawa.com/globaljs/external/jquery/plugin/jquery.cookie/jquery.cookie.js"></script>
# <script src="//static.danawa.com/globaljs/com/danawa/common/vsSearch.js"></script><script charset="utf-8" src="//static.danawa.com/globaljs/com/danawa/common/searchAutocompleteLayer_UTF8.js?v=2406251119"></script>
#
# 	<script async src='https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js'></script>
# 	<script>
# 		try {
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			window.gladsdk.cmd.push(function () {
# 				var asSlotInfo = {
# 					adUnitId: 'danawa_Web_pc_native-N725245691',
# 					adSlotElementId: 'main-rightbnr',
#
#
# 				};
# 				window.gladsdk.defineAdSlot(asSlotInfo);
# 			});
# 		}
# 		catch (err) {
# 			console.error(err);
# 		}
# 	</script>
#
#
# 					<!-- Google Tag Manager -->
# 					<script>
# 					(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 					new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 					j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 					'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 					})(window,document,'script','dataLayer','GTM-WLPCFBQ');
# 					</script>
# 					<!-- End Google Tag Manager --></head>
# <body>
#
# 					<!-- Google Tag Manager (noscript) -->
# 					<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WLPCFBQ" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>
# 					<!-- End Google Tag Manager (noscript) --><div class="skip" id="skip_navigation">
# 	<a href="#danawa_menubar" onclick="document.getElementById('danawa_menubar').tabIndex=-1;document.getElementById('danawa_menubar').focus();return false;"><span>카테고리 메뉴 바로가기</span></a>
# 	<a href="#danawa_main_container" onclick="document.getElementById('danawa_content').tabIndex=-1;document.getElementById('danawa_content').focus();return false;"><span>본문 바로가기</span></a>
# </div>
# <div id="danawa_wrap">
# 	<div class="ttop_banner">
# 	<div class="top_banner_center"><!-- banner size 1070 * 50 -->
# 		<div class="banner_type4">
# 			<iframe width="1070" scrolling="no" height="50" frameborder="0" title="광고 영역" src="//ad.danawa.com/RealMedia/ads/adstream_sx.ads/www.danawa.com/new_main@Top" marginheight="0" marginwidth="0"></iframe>
# 		</div>
# 		<a href="#top_banner_close_button" id="top_banner_close_button" onclick="return false;" class="btn_banner_close">배너닫기</a>
# 	</div>
# </div>
# 	<div class="cw-gnb">
# 		<div class="box__inner">
# 			<ul class="list__cw-gnb">
# 				<li class="list-item"><a href="https://www.enuri.com/?utm_source=onsite&utm_medium=top_gnb&utm_campaign=danawa" target="_blank" class="link__cw-gnb enuri">에누리</a></li>
# 				<li class="list-item"><a href="https://post.malltail.com/?utm_source=onsite&utm_medium=top_gnb&utm_campaign=danawa" target="_blank" class="link__cw-gnb malltail">몰테일</a></li>
# 				<li class="list-item"><a href="https://www.plto.com/?utm_source=danawa&utm_medium=referral&utm_campaign=home&utm_content=top_gnb" target="_blank" class="link__cw-gnb plto">플레이오토</a></li>
# 				<li class="list-item"><a href="https://www.makeshop.co.kr/?utm_source=onsite&utm_medium=top_gnb&utm_campaign=danawa" target="_blank" class="link__cw-gnb makeshop">메이크샵</a></li>
# 			</ul>
# 		</div>
# 	</div>
# 	<div id="danawa_header" class="main-header ">
# 		<div class="main-header__wrap">
# 			<div class="main-header__inner">
# 				<div class="main-header__banner">
# 	<h1 class="main-header__logo">
# 		<a href="https://www.danawa.com">
# 			<span class="blind">비교하고 잘 사는, 다나와</span><img src="//img.danawa.com/new/danawa_main/v1/img/danawa_logo_main_brand.png" alt="다나와 가격비교 CI" />		</a>
# 	</h1>
# 	<div class="main-header__search">
# 		<div class="search">
# 			<form id="srchFRM_TOP" name="srchFRM_TOP" style="margin: 0px">
# 				<fieldset>
# 					<legend class="blind">통합 검색</legend>
# 					<div class="search__box search_area_content">
# 	<input type="text" class="search__input" name="k1" id="AKCSearch" autocomplete="off" placeholder="검색어를 입력해주세요." title="검색어 입력" value="" />
# 	<button type="button" class="search__delete">
# 		<span class="blind">삭제</span>
# 	</button>
# 	<button type="submit" class="search__submit">
# 		<span class="blind">검색</span>
# 	</button>
#
# 	<input type="hidden" id="module" name="module" value="goods" />
# 	<input type="hidden" id="act" name="act" value="dispMain" />
# </div>
# <div id="searchBoxHidden" style="display: none"></div>
# <script>
# 	var adv_srch_type = null;
# 	var adv_srch_obj = null;
# 	var adv_srch_url = null;
#
# 	$(function() {
# 		if (typeof window.postscribe === 'function') {
# 			postscribe('#searchBoxHidden', '<script src="//ad.danawa.com/RealMedia/ads/adstream_jx.ads/www.danawa.com/main@x50"><\/script>', {
# 				done: function() {
# 					//기존에 광고스크립트 내부에서 변수 전달하는 부분을 별도로 전달 (비동기로 호출하게 되면서 불가피한 부분)
# 					window.parent.postMessage([adv_srch_type, adv_srch_obj, adv_srch_url], '*');
#
# 					$('#srchFRM_TOP').danawaSearchAutoComplete();
# 				},
# 				error: function(error) {
# 					console.error(error);
# 				}
# 			});
# 		} else {
# 			$('#srchFRM_TOP').danawaSearchAutoComplete();
# 		}
# 	});
# </script>
# 				</fieldset>
# 			</form>
# 		</div>
# 		<div id="vsSearchArea" class="search-vs" style="display: none">
#             <div class="box__search-vs-tip" style="display: none">
#             <div class="box__inner">
#                 <div class="box__contents">
#                     <span class="text__point">Tip.</span> 1개 상품명만 검색해도<br>추천 상품과 함께 스펙 비교됩니다.
#                 </div>
#                 <button type="button" class="button__nomore">
#                     <span class="text__close">다시 보지 않기</span>
#                 </button>
#             </div>
#         </div>
#         <div class="box__wrap">
#         <div class="box__search">
#             <div class="input-vs">
#                 <label for="vsSearchInputA" class="blind">VS 첫번째 상품 검색</label>
#                 <div class="box__input">
#                     <input type="text" name="vsSearchQueryA" id="vsSearchInputA" class="form__input" autocomplete="off" spellcheck="false" maxlength="100" placeholder="상품명을 입력하세요.">
#                 </div>
#             </div>
#             <div class="auto_complete_area auto_complete_area--vs" style="display: none">
#                 <div class="auto_word_list">
#                     <ul></ul>
#                 </div>
#             </div>
#         </div>
#         <div class="box__vs">
#             <div class="icon__vs"><span class="blind">vs</span></div>
#         </div>
#         <div class="box__search">
#             <div class="input-vs">
#                 <label for="vsSearchInputB" class="blind">VS 두번째 상품 검색</label>
#                 <div class="box__input">
#                     <input type="text" name="vsSearchQueryB" id="vsSearchInputB" class="form__input" autocomplete="off" spellcheck="false" maxlength="100" placeholder="상품명을 입력하세요.">
#                 </div>
#             </div>
#             <div class="auto_complete_area auto_complete_area--vs" style="display: none">
#                 <div class="auto_word_list">
#                     <ul></ul>
#                 </div>
#             </div>
#         </div>
#         <div class="box__action">
#             <button type="submit" class="button__submit"><span class="blind">vs검색</span></button>
#         </div>
#     </div>
# </div>
# <div class="toggle-vs">
#     <label>
#         <input type="checkbox" role="switch" id="vsSearchCheckbox" class="blind" autocomplete="off" disabled>
#         <span class="box__slider"></span>
#         <span class="blind">VS검색창</span>
#     </label>
#     <div id="vsSearchTooltipArea" class="box__tooltip-search-vs">
#         <button type="button" class="button__vs" aria-pressed="false" aria-describedby="vsSearchTooltip">VS검색이란</button>
#         <div id="vsSearchTooltip" class="layer-tooltip-search-vs">
#             <div class="box__inner">
#                 <div class="box__contents">스펙 비교를 한눈에 볼 수 있는 상품 비교 서비스입니다.</div>
#                 <div class="box__more">
#                     <a href="https://prod.danawa.com/vssearch/intro.php" target="_blank" class="link__more">
#                         <span class="text__close">자세히 보기</span>
#                     </a>
#                 </div>
#                 <button type="button" class="button__close">
#                     <span class="blind">닫기</span>
#                 </button>
#             </div>
#         </div>
#     </div>
# </div>
# 	</div>
# 	<div class="main-header__user">
# 		<input type="hidden" id="browserCode" value="" />
# <input type="hidden" id="memberSeq" value="" />
#
# <div class="item">
# 	<a href="#" role="button" class="btn_user btn_user--recent">
# 		<span class="txt">최근</span>
# 			</a>
# 	<div class="layer__user-recent" role="dialog" aria-label="최근 본 상품">
# 		<div class="user-recent">
# 			<div class="user-recent__wrap" id="recentProduct"></div>
# 			<div class="user-recent__wrap" id="recentCate"></div>
# 			<div class="user-recent__wrap" id="buyingGuide"></div>
# 			<button type="button" class="btn_close"><span class="blind">최근 본 상품 닫기</span></button>
# 		</div>
# 	</div>
# </div>
# <div class="item">
# 	<a href="https://www.danawa.com/main/wish/wishList.php" role="button" class="btn_user btn_user--wish">
# 		<span class="txt">관심</span>
# 			</a>
# </div>
# <div class="item">
# 	<a href="https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F" role="button" class="btn_user btn_user--login">
# 		<span class="txt">로그인</span>	</a>
# 	<div class="layer__user-more">
# 		<ul class="more-list">
# 			<li class="item_more"><a href="https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F" class="link_more">로그인</a></li><li class="item_more"><a href="https://auth.danawa.com/joinStep1" class="link_more">회원가입</a></li><li class="item_more"><a href="https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F" class="link_more">마이페이지</a></li><li class="item_more"><a href="https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F" class="link_more">쪽지</a></li><li class="item_more"><a href="http://adcenter.danawa.com" class="link_more">광고센터</a></li><li class="item_more"><a href="http://help.danawa.com" class="link_more">고객센터</a></li>		</ul>
# 	</div>
# </div>	</div>
# </div>
# 				<div id="danawa_menubar" class="main-header__menubar">
# 	<div class="main-header__category left_cagegory_all">
# 		<button type="button" class="btn_cate_all btn_cate" onclick="_trkEventLog('ca_카테고리펼쳐보기_main')"><span class="txt">전체 카테고리</span></button>
# 		<div class="category" id="category">
#     <ul id="sectionLayer" class="category__list " role="menu">
#                 <li role="menuitem" class="category__list__row" group-code="10" section-name="가전/TV">
#             <a href="#categoryHoverLayer10" role="button" class="category__list__btn" onclick="return false">가전·TV</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="11">
#             <a href="#categoryHoverLayer11" role="button" class="category__list__btn" onclick="return false">컴퓨터·노트북·조립PC</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="12">
#             <a href="#categoryHoverLayer12" role="button" class="category__list__btn" onclick="return false">태블릿·모바일·디카</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="13">
#             <a href="#categoryHoverLayer13" role="button" class="category__list__btn" onclick="return false">골프·스포츠</a>
#         </li>
#         <li role="menuitem" class="category__list__row"  group-code="14">
#             <a href="#categoryHoverLayer14" role="button" class="category__list__btn" onclick="return false">자동차·용품·공구</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="15">
#             <a href="#categoryHoverLayer15" role="button" class="category__list__btn" onclick="return false">가구·조명</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="16">
#             <a href="#categoryHoverLayer16" role="button" class="category__list__btn" onclick="return false">식품·유아·완구</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="17">
#             <a href="#categoryHoverLayer17" role="button" class="category__list__btn" onclick="return false">생활·주방·건강</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="18">
#             <a href="#categoryHoverLayer18" role="button" class="category__list__btn" onclick="return false">패션·잡화·뷰티</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="19">
#             <a href="#categoryHoverLayer19" role="button" class="category__list__btn" onclick="return false">반려동물·취미·사무</a>
#         </li>
#         <li role="menuitem" class="category__list__row" group-code="20">
#             <a href="#categoryHoverLayer20" role="button" class="category__list__btn" onclick="return false">여행·항공·호텔</a>
#         </li>
#
# 			<li role="menuitem" class="category__list__row category__list__row--rocket" group-code="21">
# 				<a href="#categoryHoverLayer21"" role="menuitem" class="category__list__btn" onclick="return false">
#                     쿠팡 로켓배송관
#                 </a>
# 			</li>    </ul>
# </div>
# <div class="category_hover_layer_wrap"></div>	</div>
# 	<div class="main-header__nav">
# 		<a href="https://auto.danawa.com/?logger_kw=dnw_gnb_auto" class="link_nav" target="blank">자동차</a>
# 		<a href="https://shop.danawa.com/shopmain/?logger_kw=dnw_gnb_pcmain" class="link_nav" target="blank">조립PC</a>
# 		<a href="https://shop.danawa.com/virtualestimate/?controller=estimateMain&methods=index&marketPlaceSeq=16&logger_kw=dnw_gnb_esti" class="link_nav" target="blank">PC견적</a>
# 		<a href="https://pc26.danawa.com/bbs/?logger_kw=dnw_gnb_pc26" class="link_nav" target="blank">PC구매상담</a>
# 		<a href="https://tour.danawa.com/?logger_kw=dnw_gnb_tour" class="link_nav" target="blank">여행</a>
# 		<a href="https://plan.danawa.com/?logger_kw=dnw_gnb_plan" class="link_nav" target="blank">쇼핑기획전</a>
# 		<a href="https://dpg.danawa.com/bbs?logger_kw=dnw_gnb_dpg" class="link_nav" target="blank">커뮤니티</a>
# 		<a href="https://event.danawa.com/?logger_kw=dnw_gnb_event" class="link_nav link_nav--event" target="blank">이벤트</a>
# 		<span class="link_nav link_nav--dv">/</span>
# 		<a href="https://event.danawa.com/experience/?logger_kw=dnw_gnb_experience" class="link_nav link_nav--experience" target="blank">체험단</a>
# 		<div class="more_nav">
# 			<button type="button" class="btn_more" id="topMenu_moreButton"><span class="blind">서비스</span>더보기</button>
# 			<!--layer__nav-more" :레이어 닫기 버튼이 없어 탭포커싱 마지막요소 이동 시 자동 닫힘 기능 구현 필요 -->
# 			<div class="layer__nav-more">
# 				<div class="more-all">
# 					<a href="https://www.danawa.com/info/map.html" class="link_all">서비스 전체보기</a>
# 				</div>
# 				<ul class="more-list">
# 					<li class="item_more"><a href="https://shop.danawa.com/main/?logger_kw=dnw_gnbmore_shopmain" class="link_more" target="_blank">샵다나와</a></li>
# 					<li class="item_more"><a href="https://brand.danawa.com/?logger_kw=dnw_gnbmore_brand" class="link_more" target="_self">브랜드로그</a></li>
# 					<li class="item_more"><a href="https://shop.danawa.com/shopmain/?controller=main&methods=usedMarket&logger_kw=dnw_gnbmore_used" class="link_more" target="_blank">중고마켓</a></li>
# 					<li class="item_more"><a href="https://dpg.danawa.com/news/movieMain?logger_kw=dnw_gnbmore_movie" class="link_more" target="_self">동영상</a></li>
# 					<li class="item_more"><a href="https://shop.danawa.com/main/?controller=used&methods=index&logger_kw=dnw_gnbmore_used_purch" class="link_more" target="_blank">중고매입</a></li>
# 					<li class="item_more"><a href="https://dasale.danawa.com/?logger_kw=dnw_gnbmore_dasale" class="link_more" target="_self">다나와특가몰</a></li>
# 					<li class="item_more"><a href="https://www.danawa.com/mobileApp/intro.php?logger_kw=dnw_gnbmore_app" class="link_more" target="_self">모바일 앱</a></li>
# 					<li class="item_more"><a href="https://shop.danawa.com/offcenter/?controller=main&methods=index&logger_kw=dnw_gnbmore_as" class="link_more" target="_blank">다나와AS</a></li>
# 					<li class="item_more"><a href="https://pc26.danawa.com/bbs/?logger_kw=dnw_gnbmore_pc26" class="link_more" target="_blank">PC26</a></li>
# 					<li class="item_more"><a href="http://shoppingguide.danawa.com" class="link_more" target="_blank">쇼핑가이드</a></li>
# 					<li class="item_more"><a href="https://dmall.danawa.com/v3/?logger_kw=dnw_gnbmore_dmall?logger_kw=dnw_gnbmore_dmall" class="link_more" target="_blank">장터</a></li>
# 				</ul>
# 			</div>
# 			<!--// layer__user-more -->
# 		</div>
# 	</div>
# </div>			</div>
# 		</div>
# 	</div>
# 	<div id="danawa_main_container">
# <div class="main-top main__inner">
# 	<div class="main-top__center">
# 		<div class="main-middlebnr" id="main-middlebnr"></div>
# 		<div class="main-info shopping-info-swiper">
# 			<div class="main__header">
# 				<h2 class="title">쇼핑정보</h2>
# 				<input type="hidden" id="shoppingInfoRandomSeq" value="5">
# 				<div class="sub-menu">
# 					<ul class="sub-menu__list">
# 														<li class="sub-menu__item col1 " id="newsMenu_1"><a href="https://dpg.danawa.com/news/" target="_blank" role="button" >주요이슈</a></li>
# 														<li class="sub-menu__item col2 " id="newsMenu_2"><a href="https://dpg.danawa.com/news/list?boardSeq=60,61,62,63,64,66,67,68,130,293,294&site=1" target="_blank" role="button" >컴퓨팅</a></li>
# 														<li class="sub-menu__item col3 sub-menu__item--select" id="newsMenu_3"><a href="http://dpg.danawa.com/news/list?boardSeq=60,61,62,63,64,65,66,67,68,130&site=4" target="_blank" role="button" >테크</a></li>
# 														<li class="sub-menu__item col1 " id="newsMenu_4"><a href="http://dpg.danawa.com/news/list?boardSeq=60,61,62,63,64,65,66,67,68,130&site=8" target="_blank" role="button" >자동차</a></li>
# 														<li class="sub-menu__item col2 " id="newsMenu_5"><a href="https://search.danawa.com/dsearch.php?query=%EA%B2%8C%EC%9E%84&tab=news" target="_blank" role="button" >HitBrand</a></li>
# 											</ul>
# 				</div>
# 			</div>
# 			<div class="main__cont">
# 				<div class="swiper-container" id="shopping-info-swiper">
# 					<div class="swiper-wrapper" id="news_room_contents">
# 						<div class='swiper-slide' id='one_0' data-section='1' ><ul class="main-info__list2"> <li class="main-info__list2__item"> 		<div class="main-info__list2__thumb"> 			<a href='http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11624&redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5613491' target='_blank' class='main-info-thumb-image__link'>				<span class='inner'>					<img src='//img.danawa.com/images/attachFiles/newsRoom/20240628/1719559092815.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*' class='img_resize' alt='아이폰 쓰면 애플 제품만 써야 할까?' onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' aria-hidden='true' />				</span>			</a> 		</div>		<div class='main-info__list2__cont'>			<a href='http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11624&redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5613491' class='link_title' target='_blank'>아이폰 쓰면 애플 제품만 써야 할까?</a> 			<a href='https://prod.danawa.com/info/?pcode=49645007' target='_blank' class='link_relate'><span class='txt'>상품보기</span></a>		</div> </li> <li class="main-info__list2__item"> 		<div class="main-info__list2__thumb"> 			<a href='http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11615&redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5613306%23' target='_blank' class='main-info-thumb-image__link'>				<span class='inner'>					<img src='//img.danawa.com/images/attachFiles/newsRoom/20240627/1719477740691.gif?fitting=Large|130:92&amp;crop=130:92;*,*' class='img_resize' alt='자동완성 얼음? 우리집에선 가능!' onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' aria-hidden='true' />				</span>			</a> 		</div>		<div class='main-info__list2__cont'>			<a href='http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11615&redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5613306%23' class='link_title' target='_blank'>자동완성 얼음? 우리집에선 가능!</a> 			<a href='https://prod.danawa.com/info/?pcode=20385347' target='_blank' class='link_relate'><span class='txt'>상품보기</span></a>		</div> </li> <li class="main-info__list2__item"> 		<div class="main-info__list2__thumb"> 			<a href='http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11605&redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D293%26listSeq%3D5612274' target='_blank' class='main-info-thumb-image__link'>				<span class='inner'>					<img src='//img.danawa.com/images/attachFiles/newsRoom/20240626/1719378420653.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*' class='img_resize' alt='더위는 에어컨에게 맡기고 시원한 여름 보내세요' onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' aria-hidden='true' />				</span>			</a> 		</div>		<div class='main-info__list2__cont'>			<a href='http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11605&redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D293%26listSeq%3D5612274' class='link_title' target='_blank'>더위는 에어컨에게 맡기고 시원한 여름 보내세요</a> 			<a href='https://prod.danawa.com/info/?pcode=19109423' target='_blank' class='link_relate'><span class='txt'>상품보기</span></a>		</div> </li> <li class="main-info__list2__item"> 		<div class="main-info__list2__thumb"> 			<a href='http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11597&redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5610490' target='_blank' class='main-info-thumb-image__link'>				<span class='inner'>					<img src='//img.danawa.com/images/attachFiles/newsRoom/20240625/1719298750277.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*' class='img_resize' alt='애플 신제품 vs 구제품, 승자는?' onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' aria-hidden='true' />				</span>			</a> 		</div>		<div class='main-info__list2__cont'>			<a href='http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11597&redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5610490' class='link_tit ...
# 				</div>
# 			</div>
# 			<div class="swipe-control">
# 				<div class="swipe-control__num">
# 					<em class="current"><span class="blind">현재</span><span id="newsRoomNowPage">5</span></em>/<span class="blind">전체</span>10				</div>
# 				<div class="swipe-control__btn">
# 					<button type="button" class="btn_prev" id="newsRoomPrevPage"><span class="blind">이전</span></button>
# 					<button type="button" class="btn_next" id="newsRoomNextPage"><span class="blind">다음</span></button>
# 					<button type="button" class="btn_stop" id="newsRoomAutoPlay"><span class="blind">자동재생 적용</span></button>
# 					<input type="hidden" id="newsRoomAutoPlayManualYN" value="N">
# 				</div>
# 			</div>
# 		</div>
# 	</div>
#
# 	<div class="main-top__right">
# 		<div class="main-lowest">
# 			<strong class="blind">최저가 추이</strong>
# 			<ul class="main-lowest__list">
# 				<li class="main-lowest__item"><a href="https://dpg.danawa.com/bbs/view?boardSeq=264&listSeq=5615141" target="_blank" class="main-lowest__link"><span class="main-lowest__name">ASUS 프리미엄 메인보드 추천 TUF Gaming B760M-PLUS II 리뷰</span></a></li><li class="main-lowest__item"><a href="https://dpg.danawa.com/news/view?boardSeq=61&listSeq=5615279" target="_blank" class="main-lowest__link"><span class="main-lowest__name">세노비스, 피부건강과 에너지까지 챙긴 ‘콜라겐 비타민 젤리’ 출시</span></a></li><li class="main-lowest__item"><a href="https://dpg.danawa.com/bbs/view?boardSeq=264&listSeq=5615125" target="_blank" class="main-lowest__link"><span class="main-lowest__name">ASUS 프리미엄 메인보드 ASUS TUF Gaming B760M-PLUS II 코잇</span></a></li>			</ul>
# 		</div>
# 		<div class="main-rightbnr" id="main-rightbnr"></div>
# 		<script>
# 			replacedNamAd = () => {
# 				let replacedNamAdSeq = Math.floor(Math.random() * 10) % 2;
# 				let replacedHtml = '';
#
# 				if (replacedNamAdSeq == 1) {
# 					replacedHtml = '<a href="https://plan.danawa.com/info/index.php?nPlanSeq=9875" target="_blank"><img src="https://img.danawa.com/img/prod/main/NB_used_422x242_1.jpg" alt="다나와 인증 중고노트북 쇼핑기획전" /></a>';
# 				}
# 				else {
# 					replacedHtml = '<a href="https://prod.danawa.com/list/?cate=11316681%2615main_11_03" target="_blank"><img src="https://img.danawa.com/img/prod/main/ad2_standardpc_422x242_2.jpg" alt="표준PC 상품리스트" /></a>';
# 				}
#
# 				$('#main-rightbnr').html(replacedHtml);
# 			}
#
# 			try {
# 				window.gladsdk.cmd.push(() => {
# 					window.gladsdk.displayAd('main-rightbnr');
# 				});
#
# 				let namAdTimeSeq = 0;
# 				let namAdRequestTimeCheck = setInterval(() => {
# 					if (namAdTimeSeq > 7) {
# 						clearInterval(namAdRequestTimeCheck);
#
# 						let namAdContentsLength = $('#main-rightbnr').html().length;
# 						if (namAdContentsLength < 1) {
# 							window.gladsdk.destroyAdSlots();
# 							replacedNamAd();
# 						}
# 					}
#
# 					namAdTimeSeq++;
# 				},
# 				200);
# 			}
# 			catch (err) {
# 				console.error(err);
# 				window.gladsdk.destroyAdSlots();
# 				replacedNamAd();
# 			}
# 		</script>
# 		<div class="main-rightbnr-btm" id="main-rightbnr-btm"></div>
# 	</div>
# </div>
#
# <div class="main-clip main__inner">
# 	<ul class="main-clip__wrap">
# 		<li class="main-clip__item main-clip__item--select" id="shoppingClipContent_1" data-zonecode="1">	<h2 class="main-clip__tab"><a href="#" class="shoppingClipTab"  role="button">PC쿨러 선택은?</a></h2>	<div class="main-clip__pannel" style=""><div class="box__big-banner"><div class="main-clip__left"><a href="https://plan.danawa.com/info/?nPlanSeq=5139&amp;logger_kw=com_sc_main2_01_240627" target="_blank" class="link_thumb"><img src="//img.danawa.com/shoppingClip/001/2024/07/01/shoppingClip1_1_20240701094501.jpg" alt="역대급 더위예상! PC쿨러 선택은?" class="thumb" onerror='src="//img.danawa.com/new/goods_list/v1/img/noimg_740x330.jpg"'></a><a href="https://plan.danawa.com/info/?nPlanSeq=5139&amp;logger_kw=com_sc_main2_01_240627" target="_blank" class="link_txt"><span class="txt"><strong class="point">역대급 더위예상! PC쿨러 선택은?</strong></span></a><a href="https://plan.danawa.com/info/?nPlanSeq=5139&amp;logger_kw=com_sc_main2_01_240627" target="_blank" class="link_go"><span class="txt">보러가기</span></a></div><div class="main-clip__left"><a href="https://plan.danawa.com/info/?nPlanSeq=10380&amp;logger_kw=com_sc_main2_02_240627" target="_blank" class="link_thumb"><img src="//img.danawa.com/shoppingClip/001/2024/07/01/shoppingClip1_2_20240701094322.jpg" alt="주요 AI 노트북 플랫폼 비교" class="thumb" onerror='src="//img.danawa.com/new/goods_list/v1/img/noimg_740x330.jpg"'></a><a href="https://plan.danawa.com/info/?nPlanSeq=10380&amp;logger_kw=com_sc_main2_02_240627" target="_blank" class="link_txt"><span class="txt"><strong class="point">주요 AI 노트북 플랫폼 비교</strong></span></a><a href="https://plan.danawa.com/info/?nPlanSeq=10380&amp;logger_kw=com_sc_main2_02_240627" target="_blank" class="link_go"><span class="txt">보러가기</span></a></div><div class="main-clip__left"><a href="https://plan.danawa.com/info/?nPlanSeq=9036&amp;logger_kw=com_sc_main2_03_240627" target="_blank" class="link_thumb"><img src="//img.danawa.com/shoppingClip/001/2024/07/01/shoppingClip1_3_20240701094502.jpg" alt="최신! 쉽게 보는 가성비 PC견적" class="thumb" onerror='src="//img.danawa.com/new/goods_list/v1/img/noimg_740x330.jpg"'></a><a href="https://plan.danawa.com/info/?nPlanSeq=9036&amp;logger_kw=com_sc_main2_03_240627" target="_blank" class="link_txt"><span class="txt"><strong class="point">최신! 쉽게 보는 가성비 PC견적</strong></span></a><a href="https://plan.danawa.com/info/?nPlanSeq=9036&amp;logger_kw=com_sc_main2_03_240627" target="_blank" class="link_go"><span class="txt">보러가기</span></a></div></div></li><li class="main-clip__item " id="shoppingClipContent_2" data-zonecode="2">	<h2 class="main-clip__tab"><a href="#" class="shoppingClipTab"  role="button">NEW LG 얼음 냉장고</a></h2>	<div class="main-clip__pannel" style="display:none;">		<div class="main-clip__left"><a href="https://plan.danawa.com/info/?nPlanSeq=10364" target="_BLANK" class="link_thumb" data-position="1"> <img src="//img.danawa.com/shoppingClip/002/2024/06/28/shoppingClip2_1_20240628103431.jpg" onerror="this.src='//img.danawa.com/new/noData/img/noImg_200_prod.gif'" alt="NEW 24년형 LG 얼음 냉장고" class="thumb"></a> <a href="https://plan.danawa.com/info/?nPlanSeq=10364" target="_BLANK" class="link_txt" data-position="1">     <span class="txt"><strong class="point">정수된 얼음이 와르르~</strong>     <br>NEW 24년형 LG 얼음 냉장고</span> </a><a href="https://plan.danawa.com/info/?nPlanSeq=10364" target="_blank" class="link_go"><span class="txt">보러가기</span></a>		</div>		<div class="main-clip__right"><a href="https://plan.danawa.com/info/index.php?nPlanSeq=10398" target="_BLANK" class="link" data-position="2"><img src="//img.danawa.com/shoppingClip/002/2024/06/28/shoppingClip2_2_20240628103433.jpg" onerror="this.src='//img.danawa.com/new/noData/img/noImg_200_prod.gif'" alt="갤럭시제트" class="imgHeightCheck"></a><a href="https://plan.danawa.com/info/index.php?nPlanSeq=10324" target="_BLANK" class="link" data-position="3"><img src="//img.danawa.com/shoppingClip/002/2024/06/28/shoppingClip2_3_20240628103435.jpg" onerror="this.src='//img.danawa.com/new/noData/img/noImg_200_prod.gif'" alt="갤워치"  ...
# 블랙 프라이데이" class="thumb" onerror='src="//img.danawa.com/new/goods_list/v1/img/noimg_740x330.jpg"'></a><a href="https://plan.danawa.com/info/index.php?nPlanSeq=10412" target="_blank" class="link_txt"><span class="txt"><strong class="point">UP TO 80%</strong><br>2024 무진장
# 블랙 프라이데이</span></a><a href="https://plan.danawa.com/info/index.php?nPlanSeq=10412" target="_blank" class="link_go"><span class="txt">보러가기</span></a></div><div class="box__grid"><div class="box__product"><a href="https://prod.danawa.com/info/?pcode=19772504" target="_blank" class="link__product"><div class="box__thumb"><img src="//img.danawa.com/prod_img/500000/504/772/img/19772504_1.jpg?shrink=144:144" alt="BAUUS C1"></div><p class="text__title">BAUUS C1</p><span class="prod-list__price"><span class="discount"><span class="blind">할인율</span><span class="rate">10</span>%</span><span class="num">24,304</span>원</span></a></div><div class="box__product"><a href="https://prod.danawa.com/info/?pcode=19772288" target="_blank" class="link__product"><div class="box__thumb"><img src="//img.danawa.com/prod_img/500000/288/772/img/19772288_1.jpg?shrink=144:144" alt="ELL"></div><p class="text__title">ELL</p><span class="prod-list__price"><span class="discount"><span class="blind">할인율</span><span class="rate">14</span>%</span><span class="num">24,304</span>원</span></a></div><div class="box__product"><a href="https://prod.danawa.com/info/?pcode=19765049" target="_blank" class="link__product"><div class="box__thumb"><img src="//img.danawa.com/prod_img/500000/049/765/img/19765049_1.jpg?shrink=144:144" alt="MOMO"></div><p class="text__title">MOMO</p><span class="prod-list__price"><span class="discount"><span class="blind">할인율</span><span class="rate">11</span>%</span><span class="num">24,304</span>원</span></a></div><div class="box__product"><a href="https://prod.danawa.com/info/?pcode=19772411" target="_blank" class="link__product"><div class="box__thumb"><img src="//img.danawa.com/prod_img/500000/411/772/img/19772411_1.jpg?shrink=144:144" alt="ZIGGY C1"></div><p class="text__title">ZIGGY C1</p><span class="prod-list__price"><span class="discount"><span class="blind">할인율</span><span class="rate">31</span>%</span><span class="num">24,304</span>원</span></a></div><div class="box__product"><a href="https://prod.danawa.com/info/?pcode=16472978" target="_blank" class="link__product"><div class="box__thumb"><img src="//img.danawa.com/prod_img/500000/978/472/img/16472978_1.jpg?shrink=100:100" alt="치코 OB221 (블랙)"></div><p class="text__title">치코 OB221 (블랙)</p><span class="prod-list__price"><span class="discount"><span class="blind">할인율</span><span class="rate">13</span>%</span><span class="num">26,910</span>원</span></a></div><div class="box__product"><a href="https://prod.danawa.com/info/?pcode=19764986" target="_blank" class="link__product"><div class="box__thumb"><img src="//img.danawa.com/prod_img/500000/986/764/img/19764986_1.jpg?shrink=100:100" alt="MONK"></div><p class="text__title">MONK</p><span class="prod-list__price"><span class="discount"><span class="blind">할인율</span><span class="rate">17</span>%</span><span class="num">24,304</span>원</span></a></div></div></div></li><li class="main-clip__item " id="shoppingClipContent_7" data-zonecode="7">	<h2 class="main-clip__tab"><a href="#" class="shoppingClipTab"  role="button">히트브랜드 대상 55% 세일</a></h2>	<div class="main-clip__pannel" style="display:none;">		<div class="main-clip__left"><a href="https://blog.naver.com/estla-tv/223490607730" target="_BLANK" class="link_thumb" data-position="1"> <img src="//img.danawa.com/shoppingClip/007/2024/07/01/shoppingClip7_1_20240701083322.jpg" onerror="this.src='//img.danawa.com/new/noData/img/noImg_200_prod.gif'" alt="UP TO 55% 특가" class="thumb"></a> <a href="https://blog.naver.com/estla-tv/223490607730" target="_BLANK" class="link_txt" data-position="1">     <span class="txt"><strong class="point">5년 연속 히트브랜드 대상</strong>     <br>UP TO 55% 특가</span> </a><a href="https://blog.naver.com/estla-tv/223490607730" target="_blank" class="link_go"><span class="txt">보러가기</span></a>		</div>		<div class="main-clip__right"><a href="https://search.danawa.com/dsearch.php?query=%EC%9D%B4%EC%8A%A4%ED%8A%B8%EB%9D%BC+%EC%BF%A0%EC%B9%B4+%ED%80%80%ED%85%80+%EC%82%AC%EC%9A%B4%EB%93%9C" ta ...
# 	 <div class="swipe-control">
#         <div class="swipe-control__btn">
#         	<input type="hidden" id="sClipCurrentPage" value="1">
# 			<input type="hidden" id="sClipTotalPage" value="11">
# 			<input type="hidden" id="sClipAutoPlayManualYN" value="N">
#             <button type="button" class="btn_prev"><span class="blind">이전</span></button>
#             <button type="button" class="btn_next"><span class="blind">다음</span></button>
#             <button type="button" class="btn_stop" id="sClipAutoPlay"><span class="blind">자동재생 멈춤</span></button>
#         </div>
#     </div>
# </div>
# <div id="gnb-fixed"></div><div class="main__grid main__inner" id="recentCmPickContainer" style="min-height: 320px;">
# 	<div class="main__grid__left" id="recentContainer">
# 	</div>
# 	<div class="main__grid__right" id="cmPickContainer">
# 	</div>
# </div>
#
# <div class="main__grid main__grid--line">
# 	<div class="main__inner">
# 		<div class="main__grid__left">
# 			<div class="main-dpg swiper-container swiper-dpg">
# 				<div class="main__header">
# 					<a href="https://dpg.danawa.com/" target="_blank">
# 						<h2 class="title">커뮤니티</h2>
# 					</a>
# 					<div class="sub-menu">
# 						<ul class="sub-menu__list">
# 							<li class="sub-menu__item" id="dpgMenu_topic"><a href="http://dpg.danawa.com/" target="_blank">토픽</a></li><li class="sub-menu__item" id="dpgMenu_best"><a href="http://dpg.danawa.com/" target="_blank">Best 커뮤니티</a></li><li class="sub-menu__item" id="dpgMenu_video"><a href="http://dpg.danawa.com/news/movieMain" target="_blank">오늘의 동영상</a></li><li class="sub-menu__item sub-menu__item--select" id="dpgMenu_dasale"><a href="http://dpg.danawa.com/bbs/dasale/list?boardSeq=265" target="_blank">특가몰</a></li>						</ul>
# 					</div>
# 				</div>
# 				<div class="main__cont swiper-wrapper">
# 													<div class="main-dpg__cont main-dpg__topic swiper-slide dpg-topic" data-section="topic">
# 									<div class="main-dpg__banner">
# 										<a href="https://event.danawa.com/dpg1_240624" target="_blank" class="main-dpg__banner__link">
# 											<img src="//img.danawa.com/images/mainCommunity/1719790296791_9dmn.jpeg" class="main-dpg__banner__img" alt="출석 이벤트">
# 										</a>
# 									</div>
# 									<ul class="main-dpg__list-thumb">
# 																					<li class="main-dpg__list-thumb__item">
# 												<a href="https://dpg.danawa.com/bbs/auction/view?boardSeq=285&listSeq=5602777" target="_blank" class="main-dpg__list-thumb__link">
# 													<img data-src="//img.danawa.com/images/mainCommunity/1717991944349_b9L3.png?fitting=Large|181:106&crop=181:106;*,*" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="도전하시겠습니까?" aria-hidden="true" class="main-dpg__list-thumb__img swiper-lazy">
# 													<span class="main-dpg__list-thumb__txt">도전하시겠습니까?</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list-thumb__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=11&listSeq=5613389" target="_blank" class="main-dpg__list-thumb__link">
# 													<img data-src="//img.danawa.com/images/mainCommunity/1719561657308_k0di.png?fitting=Large|181:106&crop=181:106;*,*" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="약 100년 전 코카콜라" aria-hidden="true" class="main-dpg__list-thumb__img swiper-lazy">
# 													<span class="main-dpg__list-thumb__txt">약 100년 전 코카콜라</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list-thumb__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=175&listSeq=5613634" target="_blank" class="main-dpg__list-thumb__link">
# 													<img data-src="//img.danawa.com/images/mainCommunity/1719561660429_gv1u.png?fitting=Large|181:106&crop=181:106;*,*" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="머리 잘하는 미용실" aria-hidden="true" class="main-dpg__list-thumb__img swiper-lazy">
# 													<span class="main-dpg__list-thumb__txt">머리 잘하는 미용실</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list-thumb__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=175&listSeq=5613850" target="_blank" class="main-dpg__list-thumb__link">
# 													<img data-src="//img.danawa.com/images/mainCommunity/1719561658843_Fanz.png?fitting=Large|181:106&crop=181:106;*,*" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="실제 빙하 색깔" aria-hidden="true" class="main-dpg__list-thumb__img swiper-lazy">
# 													<span class="main-dpg__list-thumb__txt">실제 빙하 색깔</span>
# 												</a>
# 											</li>
# 																			</ul>
# 								</div>
# 																				<div class="main-dpg__cont main-dpg__topic swiper-slide dpg-topic" data-section="topic">
# 									<ul class="main-dpg__list-thumb">
# 																					<li class="main-dpg__list-thumb__item">
# 												<a href="https://dpg.danawa.com/bbs/auction/view?boardSeq=285&listSeq=5613551" target="_blank" class="main-dpg__list-thumb__link">
# 													<img data-src="//img.danawa.com/images/mainCommunity/1719468585301_JUJJ.png?fitting=Large|181:106&crop=181:106;*,*" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="선착순 무료 참여!" aria-hidden="true" class="main-dpg__list-thumb__img swiper-lazy">
# 													<span class="main-dpg__list-thumb__txt">선착순 무료 참여!</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list-thumb__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=175&listSeq=5613103" target="_blank" class="main-dpg__list-thumb__link">
# 													<img data-src="//img.danawa.com/images/mainCommunity/1719561664336_Yr4k.png?fitting=Large|181:106&crop=181:106;*,*" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="먹으면 큰일납니다" aria-hidden="true" class="main-dpg__list-thumb__img swiper-lazy">
# 													<span class="main-dpg__list-thumb__txt">먹으면 큰일납니다</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list-thumb__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=11&listSeq=5614070" target="_blank" class="main-dpg__list-thumb__link">
# 													<img data-src="//img.danawa.com/images/mainCommunity/1719561662034_NDMU.png?fitting=Large|181:106&crop=181:106;*,*" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="요즘 아파트 근황" aria-hidden="true" class="main-dpg__list-thumb__img swiper-lazy">
# 													<span class="main-dpg__list-thumb__txt">요즘 아파트 근황</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list-thumb__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=175&listSeq=5614068" target="_blank" class="main-dpg__list-thumb__link">
# 													<img data-src="//img.danawa.com/images/mainCommunity/1719561665954_T3RI.png?fitting=Large|181:106&crop=181:106;*,*" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="홈쇼핑 방송 사고" aria-hidden="true" class="main-dpg__list-thumb__img swiper-lazy">
# 													<span class="main-dpg__list-thumb__txt">홈쇼핑 방송 사고</span>
# 												</a>
# 											</li>
# 																			</ul>
# 									<ul class="main-dpg__list">
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5588330" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">hp 빅터스 16-d1131tx 호환될까요?</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5587813" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">첫 견적 짜봤습니다</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5591506" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">기가바이트(B450) 어로스 엘리트 보드 사용 가능 여부</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5606407" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">window11 지원되나요? 스피커 감지 몇미터 까지 되나요?</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5607026" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">ASUS B85M-G 보드를 사용 중인데 hdd를 추가하고 싶습니다.</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5612315" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">외경 내경에 대해 아시는 분 있나요?</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5612628" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">호환이 가능한지 궁금합니다.</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5613557" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">노트북 인터넷 관련해서 잘 아시는분..</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5613734" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">호환 여부</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="http://dpg.danawa.com/bbs/view?boardSeq=34&listSeq=5614199" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__title">이러면 어디가 문제인거죠?</span>
# 												</a>
# 											</li>
# 																			</ul>
# 								</div>
# 																				<div class="main-dpg__cont main-dpg__community swiper-slide dpg-best" data-section="best">
# 									<ol class="main-dpg__list">											<li class="main-dpg__list__item main-dpg__list__item--thumb">
# 												<div class="main-dpg__list__thumb">
# 																											<img data-src="//img.danawa.com/images/attachFiles/6/615/5614798_18.jpg?shrink=88:66" src="//img.danawa.com/new/noData/img/noImg_200X110.gif" alt="연령별 권장 수면 시간" aria-hidden="true" class="swiper-lazy">
#
# 												</div>
# 												<a href="https://dpg.danawa.com/bbs/view?boardSeq=11&listSeq=5614798" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__rank">1</span>
# 													<span class="main-dpg__list__cmt"><span class="blind">댓글수</span>(18)</span>
# 													<span class="main-dpg__list__title"><span class="blind">글제목</span>연령별 권장 수면 시간</span>
# 												</a>
# 											</li>
# 																					<li class="main-dpg__list__item">
# 												<a href="https://dpg.danawa.com/bbs/view?boardSeq=11&listSeq=5614757" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__rank">2</span>
# 													<span class="main-dpg__list__cmt"><span class="blind">댓글수</span>(18)</span>
# 													<span class="main-dpg__list__title"><span class="blind">글제목</span>6월 출첵 개근  성공</span>
# 												</a>
# 											</li>
# 																				<li class="main-dpg__list__item">
# 												<a href="https://dpg.danawa.com/bbs/view?boardSeq=11&listSeq=5614729" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__rank">3</span>
# 													<span class="main-dpg__list__cmt"><span class="blind">댓글수</span>(12)</span>
# 													<span class="main-dpg__list__title"><span class="blind">글제목</span>일본 반도체 근황</span>
# 												</a>
# 											</li>
# 																				<li class="main-dpg__list__item">
# 												<a href="https://dpg.danawa.com/bbs/view?boardSeq=11&listSeq=5614758" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__rank">4</span>
# 													<span class="main-dpg__list__cmt"><span class="blind">댓글수</span>(10)</span>
# 													<span class="main-dpg__list__title"><span class="blind">글제목</span>칭찬이 위인을 만든다</span>
# 												</a>
# 											</li>
# 																				<li class="main-dpg__list__item">
# 												<a href="https://dpg.danawa.com/bbs/view?boardSeq=11&listSeq=5614790" target="_blank" class="main-dpg__list__link">
# 													<span class="main-dpg__list__rank">5</span>
# ...
#                         <div class="box__blank">
#                             <div class="text__comment">상품을 검색해주세요.</div>
#                         </div>
#                         <ul class="list__products"></ul>
#                         <div class="box__more" style="display: none">
#                             <button type="button" class="button__more">
#                                 <span class="text__more">더보기</span>
#                             </button>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#         <div class="box__bottom">
#             <button type="button" class="button__close">
#                 <span class="text__close">닫기</span>
#             </button>
#         </div>
#         <button type="button" class="button__close">
#             <span class="blind">닫기</span>
#         </button>
#     </div>
# </div>
# <div class="top_down_position">
# 	<div class="top_down_area">
# 		<div class="top_down_fixed">
# 			<a class="btn_layer_up" href="#"><span>컨텐츠 상단으로 이동</span></a>
# 			<a class="btn_layer_down" href="#"><span>컨텐츠 하단으로 이동</span></a>
# 		</div>
# 	</div>
# </div>
# </div>
# <!-- //danawa_container -->	</div>
# <div id="danawa_footer">
# 	<div class="footer">
# 		<div class="footer__top">
# 			<div class="footer__inner">
# 				<dl class="footer__notice">
# 					<dt class="title">공지</dt>
# 												<dd class="subj">
# 								<a href="http://help.danawa.com/noticeDetail.php?listSeq=5507260" target="_blank">다나와 사칭 사이트 주의 안내</a>
# 							</dd>
# 										</dl>
# 				<ul class="footer__menu">
# 					<li class="item"><a href="https://www.danawa.com/corp/main.html" target="_blank">다나와 소개</a></li>
# 					<li class="item"><a href="https://www.danawa.com/info/provision.html" target="_blank">이용약관</a></li>
# 					<li class="item"><a href="https://www.danawa.com/info/helprule_private.html" target="_blank">개인정보처리방침</a></li>
# 					<li class="item"><a href="https://www.danawa.com/info/boyspro.html" target="_blank">청소년 보호정책</a></li>
# 					<li class="item"><a href="https://www.danawa.com/info/map.html" target="_blank">사이트맵</a></li>
# 					<li class="item"><a href="https://adcenter.danawa.com" target="_blank">광고센터</a></li>
# 					<li class="item"><a href="https://help.danawa.com/bizCenter/index.php?depth1=1" target="_blank">협력사문의</a></li>
# 				</ul>
# 			</div>
# 		</div>
# 		<div class="footer__wrap">
# 			<div class="footer__inner">
# 				<div class="footer__info">
# 					<div class="footer__about">
# 						<span class="address">주소 (우) 08510 서울특별시 금천구 벚꽃로 298, 17층(가산동, 대륭포스트타워6차)</span>
# 						<span class="txt">대표: 이건수</span><br><span class="txt">사업자번호: 117-81-40065</span>
# 						<span class="txt">통신판매업: 제2004-서울양천-00918호</span>
# 						<span class="txt">부가통신사업: 제003081호<a href="https://www.ftc.go.kr/bizCommPop.do?wrkr_no=1178140065" class="btn_footer" target="_blank">사업자정보확인</a></span>
# 					</div>
# 					<div class="footer__law">
# 						<strong class="title">콘텐츠산업진흥법</strong><span class="summary">콘텐츠산업 진흥법에 의한 콘텐츠 보호</span>
# 						<a href="#" role="button" class="btn_footer" id="content_see_more">자세히보기</a>
# 						<div class="layer__basic" id="footer_law_layer" role="dialog" aria-label="콘텐츠산업진흥법에 의한 표시">
# 							<div class="layer__basic__wrap">
# 								<div class="layer__basic__header"><strong class="layer__basic__title">콘텐츠산업진흥법에 의한 표시</strong></div>
# 								<div class="layer__basic__cont">
# 									<div class="layer__footer-law">
# 										<div class="layer__footer-law__detail">
# 											<dl class="row">
# 												<dt class="title">콘텐츠의 명칭</dt>
# 												<dd class="cont">상품콘텐츠(정보) 및 기사, 이벤트 정보</dd>
# 											</dl>
# 											<dl class="row">
# 												<dt class="title">콘텐츠의 제작 및 표시 연월일</dt>
# 												<dd class="cont">개별 표기된 제작일 또는 갱신일</dd>
# 											</dl>
# 											<dl class="row">
# 												<dt class="title">콘텐츠의 제작자</dt>
# 												<dd class="cont">(주)커넥트웨이브<br>전화: 1688 - 2470 (유료) / 팩스: 1688-2451<br>서울특별시 양천구 목동동로 233-1 드림타워 501호</dd>
# 											</dl>
# 											<dl class="row">
# 												<dt class="title">콘텐츠의 이용조건</dt>
# 												<dd class="cont">이용약관 및 서비스 안내 참조<br>(동의 없이 무단복제 및 가공을 금함)<a href="https://www.danawa.com/info/agreement.html" target="_blank" class="btn_footer">이용약관 보기</a></dd>
# 											</dl>
# 										</div>
# 										<div class="layer__footer-law__noti">
# 											<p class="text">(주)커넥트웨이브 홈페이지 내의 모든 콘텐츠는 『콘텐츠산업 진흥법』에 따라
# 												<br> 제작일 또는 그 갱신일로부터 5년간 보호 됩니다.
# 											</p>
# 										</div>
# 									</div>
# 								</div>
# 								<button type="button" class="layer__basic__close">
# 									<span class="blind">닫기</span>
# 								</button>
# 							</div>
# 						</div>
# 						<a href="https://help.danawa.com/bizCenter/index.php?depth1=11" class="btn_footer" target="_blank">콘텐츠이용안내</a>
# 					</div>
# 					<div class="footer__point">
# 						(주)커넥트웨이브는 상품판매와 직접적인 관련이 없으며, 모든 상거래의 책임은 구매자와 판매자에게 있습니다.<br>
# 						이에 대해 (주)커넥트웨이브는 일체의 책임을 지지 않습니다.<br>
# 						본사에 등록된 모든 광고와 저작권 및 법적책임은 자료제공사 (또는 글쓴이)에게 있으므로 본사는 광고에 대한 책임을 지지 않습니다.
# 					</div>
# 					<address class="footer__copy">Copyright © <strong>connectwave</strong> Co., Ltd. All Rights Reserved.</address>
# 					<div class="footer__kolsa">
# 						<a target="_blank" href="https://www.kolsa.or.kr">
# 							<span class="blind">KOLSA 한국온라인 쇼핑협회</span>
# 						</a>
# 					</div>
# 				</div>
# 				<div class="footer__cs">
# 					<strong class="title">다나와 고객센터</strong>
# 					<div class="service">
# 						<a href="https://help.danawa.com" target="_blank" class="link link--home">고객센터 홈</a>
# 						<a href="#" target="_blank" onclick="window.open('https://help.danawa.com/onlineInquiry.php?referUrl='+ window.location.href,'_blank', 'width=800, height=900, toolbar=no, menubar=no, scrollbars=no, resizable=no, copyhistory=no'); return false;" class="link link--inquiry">신고/문의/제안</a>
# 						<a href="https://help.danawa.com/serviceHelpList.php" target="_blank" class="link link--help">서비스도움말</a>
# 					</div>
# 					<ul class="info">
# 						<li class="item">전화: 1688-2470 (유료)</li>
# 						<li class="item">팩스: 1688-2451</li>
# 						<li class="item">이메일: cs@cowave.kr</li>
# 					</ul>
# 					<ul class="relative">
# 						<li class="item">
# 							<a href="#" role="button" class="btn_footer" id="denyEmailOpenBtn" onclick="return false;">이메일수집거부</a>
# 							<div class="layer__basic" id="denyEmailNoticeArea" role="dialog" aria-label="이메일 주소 무단 수신수집 거부">
# 								<div class="layer__basic__wrap">
# 									<div class="layer__basic__header"><strong class="layer__basic__title">이메일 주소 무단 수신수집 거부</strong></div>
# 									<div class="layer__basic__cont">
# 										<div class="layer__footer-denyemail">
# 											<p class="contents">영리목적 (주)커넥트웨이브에서는 본 웹사이트에 게시된 이메일 주소가<br>
# 												전자우편 수집 프로그램이나 그 밖의 기술적 장치를 이용하여<br>
# 												무단으로 수집되는 것을 거부하며, 이를 위반시<br>
# 												<strong class="point">정보통신망법에 의해 형사처벌됨</strong>을 유념하시기 바랍니다.
# 											</p>
# 											<span class="date">[게시일 2004년 1월 16일]</span>
# 										</div>
# 									</div>
# 									<button type="button" id="denyEmailCloseBtn" class="layer__basic__close">
# 										<span class="blind">닫기</span>
# 									</button>
# 								</div>
# 							</div>
# 						</li>
# 						<li class="item">
# 							<a href="https://help.danawa.com/ars_suggestion.php" target="_blank" class="btn_footer">ARS문의안내</a>
# 						</li>
# 					</ul>
# 				</div>
# 			</div>
# 		</div>
#
# 	<script type="text/javascript">
# 		var sProductListUrl = "https://prod.danawa.com/list";
# 		var oCategoryLnb = null;
# 		var oExplodeCategoryLnb = null;
# 		var sCategoryExplodeLoggerText = "main";
#
# 		//카테고리 LNB, 펼쳐보기 draw
# 		$(document).ready(function(){
# 			oCategoryLnb = new CategoryLnb();
# 			oCategoryLnb.setListRootUrl("https://prod.danawa.com/list/");
# 			oCategoryLnb.setRootElement($(".main-header__category .category_hover_layer_wrap"));
# 			oCategoryLnb.setSectionElement($(".main-header__category #sectionLayer"));
# 		});
#
# 		_TRK_PI = "Main";
#
# 		var memberId = ""
# 	</script>
# <script src="//static.danawa.com/globaljs/external/yall/yall.min.js"></script><script src="//static.danawa.com/globaljs/external/yall/intersection-observer.js"></script><script src="//static.danawa.com/globaljs/external/modernizr/2.8.3/modernizr.custom.touch-events.js?v=2405281337"></script><script src="//static.danawa.com/globaljs/external/jquery/plugin/jquery.mousewheel/3.1.12/jquery.mousewheel.min.js?v=2405281337"></script><script src="//static.danawa.com/globaljs/static/bdl/dsas_client.min.js?v=1.0.0"></script><script src="//static.danawa.com/globaljs/com/danawa/util/common_lnb.js?v=2405281337"></script><script src="//static.danawa.com/globaljs/com/danawa/common/category/mainLNBMenu.js?v=2405281337"></script><script src="https://www.danawa.com/main/js/mainLayer.js?v=2405281337"></script><script src="https://www.danawa.com/main/js/priceCompareTop100.js?v=2405281337"></script><script src="//static.danawa.com/globaljs/com/danawa/common/category/main_lnb_ui.js?v=2405281337"></script><script src="https://www.danawa.com/main/js/mainLogger.js?v=2405281337"></script><script src="//static.danawa.com/globaljs/external/swiper/5.4.5/swiper.min.js?v=2405281337"></script><script src="//static.danawa.com/globaljs/external/postscribe/postscribe.min.js"></script>			<script>
# 				var _TRK_CP = '메인_NEW/통합메인';
# 			</script>
# 			</div>
# </div>
# </div>
# 		<script src="https://static.danawa.com/globaljs/static/logger_trackEvent.js"></script>
# 		<script src="https://static.danawa.com/globaljs/static/logger_Insight_WebAnalytics.js"></script>
# 			<script src="https://static.danawa.com/globaljs/static/wcslog.js?v1607061545="></script>
# 		<script>
# 			if (!wcs_add) var wcs_add = {};
# 			wcs_add["wa"] = "s_3b3fb74948b1";
# 			if (!_nasa) var _nasa = {};
# 			wcs.inflow("danawa.com");
# 			wcs_do(_nasa);
# 		</script>
# 		<script>
# 		var _CZN = '1';
# 	</script>
# 	<script defer src="https://static.danawa.com/globaljs/static/InsightClickZone.js"></script>
# 			<style>
# 			#t1Banner {
# 				width: 510px;
# 				height: 145px;
# 				position: absolute;
# 				left: 50%;
# 				top: 485px;
# 				margin: 0 0 0 -199px;
# 			}
# 		</style>
# 		<div id="t1Banner">
# 			<script src=""></script>
# 			<script>
# 				$('#t1Banner div[id^="adFloatLayer"]').css("z-index", 999);
# 			</script>
# 		</div>
# 		<div id="mainDim"></div>
# 		<script type="application/ld+json">
# 		{
# 			"@context": "https://schema.org",
# 			"@type": "Person",
# 			"name": "다나와",
# 			"url": "https://www.danawa.com",
# 			"sameAs": [
# 				"https://post.naver.com/my.naver?memberNo=639132",
# 				"https://www.facebook.com/danawastory",
# 				"https://play.google.com/store/apps/details?id=com.sktelecom.Danawa.Main&hl=ko",
# 				"https://itunes.apple.com/kr/app/%EB%8B%A4%EB%82%98%EC%99%80-%EA%B0%80%EA%B2%A9%EB%B9%84%EA%B5%90/id454345858?mt=8",
# 				"https://blog.naver.com/danawaelec",
# 				"https://cafe.naver.com/shopdanawa"
# 			]
# 		}
# 	</script>
# <!-- view as mobile script -->
# <script src="https://static.danawa.com/globaljs/com/danawa/common/setUpMobileView.js"></script>
#
# <!-- Google Analytics 4(GA4) -->
# <script async src="https://www.googletagmanager.com/gtag/js?id=G-L8D5P2KD8Z"></script>
# <script>
# 	window.dataLayer = window.dataLayer || [];
#
# 	function gtag() {
# 		dataLayer.push(arguments);
# 	}
# 	gtag('js', new Date());
# 	gtag('config', 'AW-963914956'); // 제휴캠페인
# 	gtag('config', 'AW-631507961'); // 확장캠페인
# 	gtag('config', 'AW-10932905353'); // 듀얼_기존
# 	gtag('config', 'AW-10933251710'); // 듀얼_확장
# 	gtag('config', 'G-L8D5P2KD8Z'); // GA4
# </script>
# 	<!-- Enliple Tracker Start -->
# 	<script>
# 		var ENP_VAR = {
# 			collect: {},
# 			conversion: {
# 				product: []
# 			}
# 		};
#
# 		(function(a, g, e, n, t) {
# 			a.enp = a.enp || function() {
# 				(a.enp.q = a.enp.q || []).push(arguments)
# 			};
# 			n = g.createElement(e);
# 			n.defer = !0;
# 			n.src = "https://cdn.megadata.co.kr/dist/prod/enp_tracker_self_hosted.min.js";
# 			t = g.getElementsByTagName(e)[0];
# 			t.parentNode.insertBefore(n, t)
# 		})(window, document, "script");
# 		enp('create', 'common', 'danawa', {
# 			device: 'W'
# 		});
# 		enp('send', 'common', 'danawa');
#
# 			</script>
# 	<!-- Enliple Tracker End -->
#
# </body>
# </html>
# '<!DOCTYPE html><html xmlns="http://www.w3.org/1999/xhtml" xml:lang="ko" lang="ko">\r\n<head>\r\n<title>스마트한 쇼핑검색, 다나와! : 가격비교 사이트</title>\r\n<meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta http-equiv="X-UA-Compatible" content="IE=Edge" /><meta name="Title" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" /><meta name="Description" content="온라인 쇼핑몰, 오픈마켓, 소셜커머스, 백화점, 전문몰 등 전 상품 정보 가격비교 사이트, 비교하면 다나와" /><meta name="Keywords" content="가격비교, 상품 추천, 가격비교사이트, 다나와, 가격비교 사이트, 가격비교 싸이트, 가격 검색, 최저가, 추천, 인터넷쇼핑, 온라인쇼핑, 쇼핑, 쇼핑몰, 싸게 파는 곳, 지식쇼핑" /><meta name="Subject" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트">\n<meta name="author" content="https://www.danawa.com">\n<meta name="robots" content="index, follow">\n<meta property="og:title" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" />\n<meta property="og:url" content="https://www.danawa.com" />\n<meta property="og:type" content="website"/>\n<meta property="og:description" content="온라인 쇼핑몰, 오픈마켓, 소셜커머스, 백화점, 전문몰 등 전 상품 정보 가격비교 사이트, 비교하면 다나와"/>\n<meta property="og:site_name" content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" />\n<meta property="og:image" content="https://img.danawa.com/new/tour/img/logo/sns_danawa.jpg"/>\n<meta name="google-site-verification" content="Zd_kQLEjiNKsk4p5LtRWR2AZFpJf5XlwGsmhy3iAukc"/>\n<meta name="naver-site-verification" content="4379d7b598f27c5fef523e358a8390cdc785ce0f"/>\n<link rel="alternate" href="https://m.danawa.com/">\n<link rel="canonical" href="https://www.danawa.com/">\n<meta content="width=1200" name="viewport" />\n<link rel="shortcut icon" href="//img.danawa.com/new/danawa_main/v1/img/danawa_favicon.ico" />\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/css/prod.main.v1.css?v=2405311423"/>\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/globaljs/external/swiper/5.4.5/swiper.min.css?v=2405311423"/>\n<link rel="stylesheet" type="text/css" href="//static.danawa.com/new/recss/wish_pop.css?v=2405311423"/>\n<script src="//static.danawa.com/globaljs/external/jquery/core/1.11.0/jquery-1.11.0.min.js?v=2406251119"></script>\n<script charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/gnb_ui.js?v=2406251119"></script>\n<script charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/jquery.addProductToWishList.js?v=2406251119"></script>\n<script src="//static.danawa.com/globaljs/external/jquery/plugin/jquery.cookie/jquery.cookie.js"></script>\n<script src="//static.danawa.com/globaljs/com/danawa/common/vsSearch.js"></script><script charset="utf-8" src="//static.danawa.com/globaljs/com/danawa/common/searchAutocompleteLayer_UTF8.js?v=2406251119"></script>\n\r\n\t<script async src=\'https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js\'></script>\r\n\t<script>\r\n\t\ttry {\r\n\t\t\twindow.gladsdk = window.gladsdk || { cmd: [] };\r\n\t\t\twindow.gladsdk.cmd.push(function () {\r\n\t\t\t\tvar asSlotInfo = {\r\n\t\t\t\t\tadUnitId: \'danawa_Web_pc_native-N725245691\',\r\n\t\t\t\t\tadSlotElementId: \'main-rightbnr\',\r\n\t\t\t\t\t\r\n\t\t\t\t\t\r\n\t\t\t\t};\r\n\t\t\t\twindow.gladsdk.defineAdSlot(asSlotInfo);\r\n\t\t\t});\r\n\t\t}\r\n\t\tcatch (err) {\r\n\t\t\tconsole.error(err);\r\n\t\t}\r\n\t</script>\r\n\t\n\r\n\t\t\t\t\t<!-- Google Tag Manager -->\r\n\t\t\t\t\t<script>\r\n\t\t\t\t\t(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({\'gtm.start\':\r\n\t\t\t\t\tnew Date().getTime(),event:\'gtm.js\'});var f=d.getElementsByTagName(s)[0],\r\n\t\t\t\t\tj=d.createElement(s),dl=l!=\'dataLayer\'?\'&l=\'+l:\'\';j.async=true;j.src=\r\n\t\t\t\t\t\'https://www.googletagmanager.com/gtm.js?id=\'+i+dl;f.parentNode.insertBefore(j,f);\r\n\t\t\t\t\t})(window,document,\'script\',\'dataLayer\',\'GTM-WLPCFBQ\');\r\n\t\t\t\t\t</script>\r\n\t\t\t\t\t<!-- End Google Tag Manager --></head>\r\n<body>\r\n    \r\n\t\t\t\t\t<!-- Google Tag Manager (noscript) -->\r\n\t\t\t\t\t<noscript><iframe src="https://www.googletagmanager.com/ns.html?id=GTM-WLPCFBQ" height="0" width="0" style="display:none;visibility:hidden"></iframe></noscript>\r\n\t\t\t\t\ ...

# %%
# 파싱 : 변환되지 않을 수도 있는 것을 변환하는 행위 -> 위험하다 / 예외처리가 필요(try-catch)
soup = bs(res.text, "html.parser")  # text를 html dom으로 파싱하겠다
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ko" xml:lang="ko" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    스마트한 쇼핑검색, 다나와! : 가격비교 사이트
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" name="Title"/>
#   <meta content="온라인 쇼핑몰, 오픈마켓, 소셜커머스, 백화점, 전문몰 등 전 상품 정보 가격비교 사이트, 비교하면 다나와" name="Description"/>
#   <meta content="가격비교, 상품 추천, 가격비교사이트, 다나와, 가격비교 사이트, 가격비교 싸이트, 가격 검색, 최저가, 추천, 인터넷쇼핑, 온라인쇼핑, 쇼핑, 쇼핑몰, 싸게 파는 곳, 지식쇼핑" name="Keywords"/>
#   <meta content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" name="Subject"/>
#   <meta content="https://www.danawa.com" name="author"/>
#   <meta content="index, follow" name="robots"/>
#   <meta content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" property="og:title">
#    <meta content="https://www.danawa.com" property="og:url">
#     <meta content="website" property="og:type">
#      <meta content="온라인 쇼핑몰, 오픈마켓, 소셜커머스, 백화점, 전문몰 등 전 상품 정보 가격비교 사이트, 비교하면 다나와" property="og:description"/>
#      <meta content="스마트한 쇼핑검색, 다나와! : 가격비교 사이트" property="og:site_name"/>
#      <meta content="https://img.danawa.com/new/tour/img/logo/sns_danawa.jpg" property="og:image"/>
#      <meta content="Zd_kQLEjiNKsk4p5LtRWR2AZFpJf5XlwGsmhy3iAukc" name="google-site-verification"/>
#      <meta content="4379d7b598f27c5fef523e358a8390cdc785ce0f" name="naver-site-verification"/>
#      <link href="https://m.danawa.com/" rel="alternate"/>
#      <link href="https://www.danawa.com/" rel="canonical"/>
#      <meta content="width=1200" name="viewport"/>
#      <link href="//img.danawa.com/new/danawa_main/v1/img/danawa_favicon.ico" rel="shortcut icon">
#       <link href="//static.danawa.com/css/prod.main.v1.css?v=2405311423" rel="stylesheet" type="text/css">
#        <link href="//static.danawa.com/globaljs/external/swiper/5.4.5/swiper.min.css?v=2405311423" rel="stylesheet" type="text/css"/>
#        <link href="//static.danawa.com/new/recss/wish_pop.css?v=2405311423" rel="stylesheet" type="text/css"/>
#        <script src="//static.danawa.com/globaljs/external/jquery/core/1.11.0/jquery-1.11.0.min.js?v=2406251119">
#        </script>
#        <script charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/gnb_ui.js?v=2406251119">
#        </script>
#        <script charset="euc-kr" src="//static.danawa.com/globaljs/com/danawa/common/jquery.addProductToWishList.js?v=2406251119">
#        </script>
#        <script src="//static.danawa.com/globaljs/external/jquery/plugin/jquery.cookie/jquery.cookie.js">
#        </script>
#        <script src="//static.danawa.com/globaljs/com/danawa/common/vsSearch.js">
#        </script>
#        <script charset="utf-8" src="//static.danawa.com/globaljs/com/danawa/common/searchAutocompleteLayer_UTF8.js?v=2406251119">
#        </script>
#        <script async="" src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js">
#        </script>
#        <script>
#         try {
# 			window.gladsdk = window.gladsdk || { cmd: [] };
# 			window.gladsdk.cmd.push(function () {
# 				var asSlotInfo = {
# 					adUnitId: 'danawa_Web_pc_native-N725245691',
# 					adSlotElementId: 'main-rightbnr',
#
#
# 				};
# 				window.gladsdk.defineAdSlot(asSlotInfo);
# 			});
# 		}
# 		catch (err) {
# 			console.error(err);
# 		}
#        </script>
#        <!-- Google Tag Manager -->
#        <script>
#         (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 					new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 					j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 					'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# 					})(window,document,'script','dataLayer','GTM-WLPCFBQ');
#        </script>
#        <!-- End Google Tag Manager -->
#       </link>
#      </link>
#     </meta>
#    </meta>
#   </meta>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-WLPCFBQ" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div class="skip" id="skip_navigation">
#    <a href="#danawa_menubar" onclick="document.getElementById('danawa_menubar').tabIndex=-1;document.getElementById('danawa_menubar').focus();return false;">
#     <span>
#      카테고리 메뉴 바로가기
#     </span>
#    </a>
#    <a href="#danawa_main_container" onclick="document.getElementById('danawa_content').tabIndex=-1;document.getElementById('danawa_content').focus();return false;">
#     <span>
#      본문 바로가기
#     </span>
#    </a>
#   </div>
#   <div id="danawa_wrap">
#    <div class="ttop_banner">
#     <div class="top_banner_center">
#      <!-- banner size 1070 * 50 -->
#      <div class="banner_type4">
#       <iframe frameborder="0" height="50" marginheight="0" marginwidth="0" scrolling="no" src="//ad.danawa.com/RealMedia/ads/adstream_sx.ads/www.danawa.com/new_main@Top" title="광고 영역" width="1070">
#       </iframe>
#      </div>
#      <a class="btn_banner_close" href="#top_banner_close_button" id="top_banner_close_button" onclick="return false;">
#       배너닫기
#      </a>
#     </div>
#    </div>
#    <div class="cw-gnb">
#     <div class="box__inner">
#      <ul class="list__cw-gnb">
#       <li class="list-item">
#        <a class="link__cw-gnb enuri" href="https://www.enuri.com/?utm_source=onsite&amp;utm_medium=top_gnb&amp;utm_campaign=danawa" target="_blank">
#         에누리
#        </a>
#       </li>
#       <li class="list-item">
#        <a class="link__cw-gnb malltail" href="https://post.malltail.com/?utm_source=onsite&amp;utm_medium=top_gnb&amp;utm_campaign=danawa" target="_blank">
#         몰테일
#        </a>
#       </li>
#       <li class="list-item">
#        <a class="link__cw-gnb plto" href="https://www.plto.com/?utm_source=danawa&amp;utm_medium=referral&amp;utm_campaign=home&amp;utm_content=top_gnb" target="_blank">
#         플레이오토
#        </a>
#       </li>
#       <li class="list-item">
#        <a class="link__cw-gnb makeshop" href="https://www.makeshop.co.kr/?utm_source=onsite&amp;utm_medium=top_gnb&amp;utm_campaign=danawa" target="_blank">
#         메이크샵
#        </a>
#       </li>
#      </ul>
#     </div>
#    </div>
#    <div class="main-header" id="danawa_header">
#     <div class="main-header__wrap">
#      <div class="main-header__inner">
#       <div class="main-header__banner">
#        <h1 class="main-header__logo">
#         <a href="https://www.danawa.com">
#          <span class="blind">
#           비교하고 잘 사는, 다나와
#          </span>
#          <img alt="다나와 가격비교 CI" src="//img.danawa.com/new/danawa_main/v1/img/danawa_logo_main_brand.png"/>
#         </a>
#        </h1>
#        <div class="main-header__search">
#         <div class="search">
#          <form id="srchFRM_TOP" name="srchFRM_TOP" style="margin: 0px">
#           <fieldset>
#            <legend class="blind">
#             통합 검색
#            </legend>
#            <div class="search__box search_area_content">
#             <input autocomplete="off" class="search__input" id="AKCSearch" name="k1" placeholder="검색어를 입력해주세요." title="검색어 입력" type="text" value=""/>
#             <button class="search__delete" type="button">
#              <span class="blind">
#               삭제
#              </span>
#             </button>
#             <button class="search__submit" type="submit">
#              <span class="blind">
#               검색
#              </span>
#             </button>
#             <input id="module" name="module" type="hidden" value="goods"/>
#             <input id="act" name="act" type="hidden" value="dispMain"/>
#            </div>
#            <div id="searchBoxHidden" style="display: none">
#            </div>
#            <script>
#             var adv_srch_type = null;
# 	var adv_srch_obj = null;
# 	var adv_srch_url = null;
#
# 	$(function() {
# 		if (typeof window.postscribe === 'function') {
# 			postscribe('#searchBoxHidden', '<script src="//ad.danawa.com/RealMedia/ads/adstream_jx.ads/www.danawa.com/main@x50"><\/script>', {
# 				done: function() {
# 					//기존에 광고스크립트 내부에서 변수 전달하는 부분을 별도로 전달 (비동기로 호출하게 되면서 불가피한 부분)
# 					window.parent.postMessage([adv_srch_type, adv_srch_obj, adv_srch_url], '*');
#
# 					$('#srchFRM_TOP').danawaSearchAutoComplete();
# 				},
# 				error: function(error) {
# 					console.error(error);
# 				}
# 			});
# 		} else {
# 			$('#srchFRM_TOP').danawaSearchAutoComplete();
# 		}
# 	});
#            </script>
#           </fieldset>
#          </form>
#         </div>
#         <div class="search-vs" id="vsSearchArea" style="display: none">
#          <div class="box__search-vs-tip" style="display: none">
#           <div class="box__inner">
#            <div class="box__contents">
#             <span class="text__point">
#              Tip.
#             </span>
#             1개 상품명만 검색해도
#             <br/>
#             추천 상품과 함께 스펙 비교됩니다.
#            </div>
#            <button class="button__nomore" type="button">
#             <span class="text__close">
#              다시 보지 않기
#             </span>
#            </button>
#           </div>
#          </div>
#          <div class="box__wrap">
#           <div class="box__search">
#            <div class="input-vs">
#             <label class="blind" for="vsSearchInputA">
#              VS 첫번째 상품 검색
#             </label>
#             <div class="box__input">
#              <input autocomplete="off" class="form__input" id="vsSearchInputA" maxlength="100" name="vsSearchQueryA" placeholder="상품명을 입력하세요." spellcheck="false" type="text"/>
#             </div>
#            </div>
#            <div class="auto_complete_area auto_complete_area--vs" style="display: none">
#             <div class="auto_word_list">
#              <ul>
#              </ul>
#             </div>
#            </div>
#           </div>
#           <div class="box__vs">
#            <div class="icon__vs">
#             <span class="blind">
#              vs
#             </span>
#            </div>
#           </div>
#           <div class="box__search">
#            <div class="input-vs">
#             <label class="blind" for="vsSearchInputB">
#              VS 두번째 상품 검색
#             </label>
#             <div class="box__input">
#              <input autocomplete="off" class="form__input" id="vsSearchInputB" maxlength="100" name="vsSearchQueryB" placeholder="상품명을 입력하세요." spellcheck="false" type="text"/>
#             </div>
#            </div>
#            <div class="auto_complete_area auto_complete_area--vs" style="display: none">
#             <div class="auto_word_list">
#              <ul>
#              </ul>
#             </div>
#            </div>
#           </div>
#           <div class="box__action">
#            <button class="button__submit" type="submit">
#             <span class="blind">
#              vs검색
#             </span>
#            </button>
#           </div>
#          </div>
#         </div>
#         <div class="toggle-vs">
#          <label>
#           <input autocomplete="off" class="blind" disabled="" id="vsSearchCheckbox" role="switch" type="checkbox"/>
#           <span class="box__slider">
#           </span>
#           <span class="blind">
#            VS검색창
#           </span>
#          </label>
#          <div class="box__tooltip-search-vs" id="vsSearchTooltipArea">
#           <button aria-describedby="vsSearchTooltip" aria-pressed="false" class="button__vs" type="button">
#            VS검색이란
#           </button>
#           <div class="layer-tooltip-search-vs" id="vsSearchTooltip">
#            <div class="box__inner">
#             <div class="box__contents">
#              스펙 비교를 한눈에 볼 수 있는 상품 비교 서비스입니다.
#             </div>
#             <div class="box__more">
#              <a class="link__more" href="https://prod.danawa.com/vssearch/intro.php" target="_blank">
#               <span class="text__close">
#                자세히 보기
#               </span>
#              </a>
#             </div>
#             <button class="button__close" type="button">
#              <span class="blind">
#               닫기
#              </span>
#             </button>
#            </div>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="main-header__user">
#         <input id="browserCode" type="hidden" value="">
#          <input id="memberSeq" type="hidden" value="">
#           <div class="item">
#            <a class="btn_user btn_user--recent" href="#" role="button">
#             <span class="txt">
#              최근
#             </span>
#            </a>
#            <div aria-label="최근 본 상품" class="layer__user-recent" role="dialog">
#             <div class="user-recent">
#              <div class="user-recent__wrap" id="recentProduct">
#              </div>
#              <div class="user-recent__wrap" id="recentCate">
#              </div>
#              <div class="user-recent__wrap" id="buyingGuide">
#              </div>
#              <button class="btn_close" type="button">
#               <span class="blind">
#                최근 본 상품 닫기
#               </span>
#              </button>
#             </div>
#            </div>
#           </div>
#           <div class="item">
#            <a class="btn_user btn_user--wish" href="https://www.danawa.com/main/wish/wishList.php" role="button">
#             <span class="txt">
#              관심
#             </span>
#            </a>
#           </div>
#           <div class="item">
#            <a class="btn_user btn_user--login" href="https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F" role="button">
#             <span class="txt">
#              로그인
#             </span>
#            </a>
#            <div class="layer__user-more">
#             <ul class="more-list">
#              <li class="item_more">
#               <a class="link_more" href="https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F">
#                로그인
#               </a>
#              </li>
#              <li class="item_more">
#               <a class="link_more" href="https://auth.danawa.com/joinStep1">
#                회원가입
#               </a>
#              </li>
#              <li class="item_more">
#               <a class="link_more" href="https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F">
#                마이페이지
#               </a>
#              </li>
#              <li class="item_more">
#               <a class="link_more" href="https://auth.danawa.com/login?url=https%3A%2F%2Fwww.danawa.com%2F">
#                쪽지
#               </a>
#              </li>
#              <li class="item_more">
#               <a class="link_more" href="http://adcenter.danawa.com">
#                광고센터
#               </a>
#              </li>
#              <li class="item_more">
#               <a class="link_more" href="http://help.danawa.com">
#                고객센터
#               </a>
#              </li>
#             </ul>
#            </div>
#           </div>
#          </input>
#         </input>
#        </div>
#       </div>
#       <div class="main-header__menubar" id="danawa_menubar">
#        <div class="main-header__category left_cagegory_all">
#         <button class="btn_cate_all btn_cate" onclick="_trkEventLog('ca_카테고리펼쳐보기_main')" type="button">
#          <span class="txt">
#           전체 카테고리
#          </span>
#         </button>
#         <div class="category" id="category">
#          <ul class="category__list" id="sectionLayer" role="menu">
#           <li class="category__list__row" group-code="10" role="menuitem" section-name="가전/TV">
#            <a class="category__list__btn" href="#categoryHoverLayer10" onclick="return false" role="button">
#             가전·TV
#            </a>
#           </li>
#           <li class="category__list__row" group-code="11" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer11" onclick="return false" role="button">
#             컴퓨터·노트북·조립PC
#            </a>
#           </li>
#           <li class="category__list__row" group-code="12" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer12" onclick="return false" role="button">
#             태블릿·모바일·디카
#            </a>
#           </li>
#           <li class="category__list__row" group-code="13" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer13" onclick="return false" role="button">
#             골프·스포츠
#            </a>
#           </li>
#           <li class="category__list__row" group-code="14" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer14" onclick="return false" role="button">
#             자동차·용품·공구
#            </a>
#           </li>
#           <li class="category__list__row" group-code="15" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer15" onclick="return false" role="button">
#             가구·조명
#            </a>
#           </li>
#           <li class="category__list__row" group-code="16" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer16" onclick="return false" role="button">
#             식품·유아·완구
#            </a>
#           </li>
#           <li class="category__list__row" group-code="17" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer17" onclick="return false" role="button">
#             생활·주방·건강
#            </a>
#           </li>
#           <li class="category__list__row" group-code="18" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer18" onclick="return false" role="button">
#             패션·잡화·뷰티
#            </a>
#           </li>
#           <li class="category__list__row" group-code="19" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer19" onclick="return false" role="button">
#             반려동물·취미·사무
#            </a>
#           </li>
#           <li class="category__list__row" group-code="20" role="menuitem">
#            <a class="category__list__btn" href="#categoryHoverLayer20" onclick="return false" role="button">
#             여행·항공·호텔
#            </a>
#           </li>
#           <li class="category__list__row category__list__row--rocket" group-code="21" role="menuitem">
#            <a "="" class="category__list__btn" href="#categoryHoverLayer21" onclick="return false" role="menuitem">
#             쿠팡 로켓배송관
#            </a>
#           </li>
#          </ul>
#         </div>
#         <div class="category_hover_layer_wrap">
#         </div>
#        </div>
#        <div class="main-header__nav">
#         <a class="link_nav" href="https://auto.danawa.com/?logger_kw=dnw_gnb_auto" target="blank">
#          자동차
#         </a>
#         <a class="link_nav" href="https://shop.danawa.com/shopmain/?logger_kw=dnw_gnb_pcmain" target="blank">
#          조립PC
#         </a>
#         <a class="link_nav" href="https://shop.danawa.com/virtualestimate/?controller=estimateMain&amp;methods=index&amp;marketPlaceSeq=16&amp;logger_kw=dnw_gnb_esti" target="blank">
#          PC견적
#         </a>
#         <a class="link_nav" href="https://pc26.danawa.com/bbs/?logger_kw=dnw_gnb_pc26" target="blank">
#          PC구매상담
#         </a>
#         <a class="link_nav" href="https://tour.danawa.com/?logger_kw=dnw_gnb_tour" target="blank">
#          여행
#         </a>
#         <a class="link_nav" href="https://plan.danawa.com/?logger_kw=dnw_gnb_plan" target="blank">
#          쇼핑기획전
#         </a>
#         <a class="link_nav" href="https://dpg.danawa.com/bbs?logger_kw=dnw_gnb_dpg" target="blank">
#          커뮤니티
#         </a>
#         <a class="link_nav link_nav--event" href="https://event.danawa.com/?logger_kw=dnw_gnb_event" target="blank">
#          이벤트
#         </a>
#         <span class="link_nav link_nav--dv">
#          /
#         </span>
#         <a class="link_nav link_nav--experience" href="https://event.danawa.com/experience/?logger_kw=dnw_gnb_experience" target="blank">
#          체험단
#         </a>
#         <div class="more_nav">
#          <button class="btn_more" id="topMenu_moreButton" type="button">
#           <span class="blind">
#            서비스
#           </span>
#           더보기
#          </button>
#          <!--layer__nav-more" :레이어 닫기 버튼이 없어 탭포커싱 마지막요소 이동 시 자동 닫힘 기능 구현 필요 -->
#          <div class="layer__nav-more">
#           <div class="more-all">
#            <a class="link_all" href="https://www.danawa.com/info/map.html">
#             서비스 전체보기
#            </a>
#           </div>
#           <ul class="more-list">
#            <li class="item_more">
#             <a class="link_more" href="https://shop.danawa.com/main/?logger_kw=dnw_gnbmore_shopmain" target="_blank">
#              샵다나와
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://brand.danawa.com/?logger_kw=dnw_gnbmore_brand" target="_self">
#              브랜드로그
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://shop.danawa.com/shopmain/?controller=main&amp;methods=usedMarket&amp;logger_kw=dnw_gnbmore_used" target="_blank">
#              중고마켓
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://dpg.danawa.com/news/movieMain?logger_kw=dnw_gnbmore_movie" target="_self">
#              동영상
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://shop.danawa.com/main/?controller=used&amp;methods=index&amp;logger_kw=dnw_gnbmore_used_purch" target="_blank">
#              중고매입
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://dasale.danawa.com/?logger_kw=dnw_gnbmore_dasale" target="_self">
#              다나와특가몰
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://www.danawa.com/mobileApp/intro.php?logger_kw=dnw_gnbmore_app" target="_self">
#              모바일 앱
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://shop.danawa.com/offcenter/?controller=main&amp;methods=index&amp;logger_kw=dnw_gnbmore_as" target="_blank">
#              다나와AS
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://pc26.danawa.com/bbs/?logger_kw=dnw_gnbmore_pc26" target="_blank">
#              PC26
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="http://shoppingguide.danawa.com" target="_blank">
#              쇼핑가이드
#             </a>
#            </li>
#            <li class="item_more">
#             <a class="link_more" href="https://dmall.danawa.com/v3/?logger_kw=dnw_gnbmore_dmall?logger_kw=dnw_gnbmore_dmall" target="_blank">
#              장터
#             </a>
#            </li>
#           </ul>
#          </div>
#          <!--// layer__user-more -->
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div id="danawa_main_container">
#     <div class="main-top main__inner">
#      <div class="main-top__center">
#       <div class="main-middlebnr" id="main-middlebnr">
#       </div>
#       <div class="main-info shopping-info-swiper">
#        <div class="main__header">
#         <h2 class="title">
#          쇼핑정보
#         </h2>
#         <input id="shoppingInfoRandomSeq" type="hidden" value="5"/>
#         <div class="sub-menu">
#          <ul class="sub-menu__list">
#           <li class="sub-menu__item col1" id="newsMenu_1">
#            <a href="https://dpg.danawa.com/news/" role="button" target="_blank">
#             주요이슈
#            </a>
#           </li>
#           <li class="sub-menu__item col2" id="newsMenu_2">
#            <a href="https://dpg.danawa.com/news/list?boardSeq=60,61,62,63,64,66,67,68,130,293,294&amp;site=1" role="button" target="_blank">
#             컴퓨팅
#            </a>
#           </li>
#           <li class="sub-menu__item col3 sub-menu__item--select" id="newsMenu_3">
#            <a href="http://dpg.danawa.com/news/list?boardSeq=60,61,62,63,64,65,66,67,68,130&amp;site=4" role="button" target="_blank">
#             테크
#            </a>
#           </li>
#           <li class="sub-menu__item col1" id="newsMenu_4">
#            <a href="http://dpg.danawa.com/news/list?boardSeq=60,61,62,63,64,65,66,67,68,130&amp;site=8" role="button" target="_blank">
#             자동차
#            </a>
#           </li>
#           <li class="sub-menu__item col2" id="newsMenu_5">
#            <a href="https://search.danawa.com/dsearch.php?query=%EA%B2%8C%EC%9E%84&amp;tab=news" role="button" target="_blank">
#             HitBrand
#            </a>
#           </li>
#          </ul>
#         </div>
#        </div>
#        <div class="main__cont">
#         <div class="swiper-container" id="shopping-info-swiper">
#          <div class="swiper-wrapper" id="news_room_contents">
#           <div class="swiper-slide" data-section="1" id="one_0">
#            <ul class="main-info__list2">
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11624&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5613491" target="_blank">
#                <span class="inner">
#                 <img alt="아이폰 쓰면 애플 제품만 써야 할까?" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240628/1719559092815.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11624&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5613491" target="_blank">
#                아이폰 쓰면 애플 제품만 써야 할까?
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=49645007" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11615&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5613306%23" target="_blank">
#                <span class="inner">
#                 <img alt="자동완성 얼음? 우리집에선 가능!" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240627/1719477740691.gif?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11615&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5613306%23" target="_blank">
#                자동완성 얼음? 우리집에선 가능!
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=20385347" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11605&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D293%26listSeq%3D5612274" target="_blank">
#                <span class="inner">
#                 <img alt="더위는 에어컨에게 맡기고 시원한 여름 보내세요" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240626/1719378420653.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11605&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D293%26listSeq%3D5612274" target="_blank">
#                더위는 에어컨에게 맡기고 시원한 여름 보내세요
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=19109423" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11597&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5610490" target="_blank">
#                <span class="inner">
#                 <img alt="애플 신제품 vs 구제품, 승자는?" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240625/1719298750277.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11597&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5610490" target="_blank">
#                애플 신제품 vs 구제품, 승자는?
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=15253211" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="swiper-slide" data-section="1" id="one_1">
#            <ul class="main-info__list2">
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11600&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5609935" target="_blank">
#                <span class="inner">
#                 <img alt="두 개의 심장을 가진 냉장고" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240626/1719383190017.gif?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11600&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5609935" target="_blank">
#                두 개의 심장을 가진 냉장고
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=45594554" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11599&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FlistSeq%3D5610386%26boardSeq%3D63" target="_blank">
#                <span class="inner">
#                 <img alt="삼성 갤럭시북, 라인업 헷갈리시죠?" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240625/1719300395770.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11599&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FlistSeq%3D5610386%26boardSeq%3D63" target="_blank">
#                삼성 갤럭시북, 라인업 헷갈리시죠?
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=44762393" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11571&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D64%26listSeq%3D5606267%23" target="_blank">
#                <span class="inner">
#                 <img alt="2024 러닝화 계급도" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240621/1718950035599.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11571&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D64%26listSeq%3D5606267%23" target="_blank">
#                2024 러닝화 계급도
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=55381880" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11592&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5611579" target="_blank">
#                <span class="inner">
#                 <img alt="아이패드 프로가 맥북 대체할까?" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240624/1719224079555.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11592&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5611579" target="_blank">
#                아이패드 프로가 맥북 대체할까?
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=49645475" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="swiper-slide" data-section="2" id="two_0">
#            <ul class="main-info__list2">
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11618&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D294%26listSeq%3D5613686" target="_blank">
#                <span class="inner">
#                 <img alt="삼성이 DRAM 공급가를 올린다고?" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240627/1719479025916.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11618&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D294%26listSeq%3D5613686" target="_blank">
#                삼성이 DRAM 공급가를 올린다고?
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11574&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D60%26listSeq%3D5610462" target="_blank">
#                <span class="inner">
#                 <img alt="내장그래픽이 3050이랑 동급?" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240621/1718959030116.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11574&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D60%26listSeq%3D5610462" target="_blank">
#                내장그래픽이 3050이랑 동급?
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11586&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D62%26listSeq%3D5610557" target="_blank">
#                <span class="inner">
#                 <img alt="PC안에 카리나가 아아~ 오~에~" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240624/1719204862847.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11586&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D62%26listSeq%3D5610557" target="_blank">
#                PC안에 카리나가 아아~ 오~에~
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=53524424" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11613&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FlistSeq%3D5613352%26boardSeq%3D62" target="_blank">
#                <span class="inner">
#                 <img alt="삼박자를 만족하는 어항 케이스" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240627/1719471533968.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11613&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FlistSeq%3D5613352%26boardSeq%3D62" target="_blank">
#                삼박자를 만족하는 어항 케이스
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=52152821" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="swiper-slide" data-section="2" id="two_1">
#            <ul class="main-info__list2">
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11603&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2FmovieDetail%3FlistSeq%3D5612673" target="_blank">
#                <span class="inner">
#                 <img alt="역대급 미니 PC의 귀환" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240626/1719368761255.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11603&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2FmovieDetail%3FlistSeq%3D5612673" target="_blank">
#                역대급 미니 PC의 귀환
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=54814211" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11591&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FlistSeq%3D5611737%26boardSeq%3D62" target="_blank">
#                <span class="inner">
#                 <img alt="대세 디자인으로 환골탈태" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240624/1719216340429.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11591&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FlistSeq%3D5611737%26boardSeq%3D62" target="_blank">
#                대세 디자인으로 환골탈태
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11587&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D62%26listSeq%3D5611597" target="_blank">
#                <span class="inner">
#                 <img alt="압도적 성능, 완벽한 선 정리" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240624/1719204966905.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11587&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D62%26listSeq%3D5611597" target="_blank">
#                압도적 성능, 완벽한 선 정리
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=49539176" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11570&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5610431" target="_blank">
#                <span class="inner">
#                 <img alt="개발자 4인의 키보드 찐템은?" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240621/1718949156129.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11570&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D63%26listSeq%3D5610431" target="_blank">
#                개발자 4인의 키보드 찐템은?
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=12438863" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#            </ul>
#           </div>
#           <div class="swiper-slide" data-section="3" data-swiper-autoplay="7000" id="three_0">
#            <ul class="main-info__list2">
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11612&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2FmovieDetail%3FlistSeq%3D5613157" target="_blank">
#                <span class="inner">
#                 <img alt="청소가 귀찮은 사람에게 필수템!" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240627/1719454243661.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11612&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2FmovieDetail%3FlistSeq%3D5613157" target="_blank">
#                청소가 귀찮은 사람에게 필수템!
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=31655570" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11588&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2FmovieDetail%3FlistSeq%3D5610598" target="_blank">
#                <span class="inner">
#                 <img alt="헤드폰 안에 동글 있다" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240624/1719213445516.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
#               <a class="link_title" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11588&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2FmovieDetail%3FlistSeq%3D5610598" target="_blank">
#                헤드폰 안에 동글 있다
#               </a>
#               <a class="link_relate" href="https://prod.danawa.com/info/?pcode=57493382" target="_blank">
#                <span class="txt">
#                 상품보기
#                </span>
#               </a>
#              </div>
#             </li>
#             <li class="main-info__list2__item">
#              <div class="main-info__list2__thumb">
#               <a class="main-info-thumb-image__link" href="http://dpg.danawa.com/bbs/newsRoomBridge?newsRoomItemSeq=11563&amp;redirectUrl=https%3A%2F%2Fdpg.danawa.com%2Fnews%2Fview%3FboardSeq%3D64%26listSeq%3D5609841" target="_blank">
#                <span class="inner">
#                 <img alt="100MB만 들고 다녀도 온 세상이 내 것 같았던 시절" aria-hidden="true" class="img_resize" onerror='this.src="//img.danawa.com/new/noData/img/nolmg_320x240.jpg"' src="//img.danawa.com/images/attachFiles/newsRoom/20240620/1718866331206.jpeg?fitting=Large|130:92&amp;crop=130:92;*,*"/>
#                </span>
#               </a>
#              </div>
#              <div class="main-info__list2__cont">
# ...
#           </button>
#          </li>
#          <li class="list-item" role="presentation">
#           <button aria-controls="vsSearchAddLayerTabPanel3" aria-selected="false" class="button__tab" id="vsSearchAddLayerTabButton3" role="tab" type="button">
#            <span class="text__tab">
#             키워드 검색
#            </span>
#           </button>
#          </li>
#         </ul>
#         <div class="box__search">
#          <div class="input-keyword">
#           <label class="blind" for="vsSearchAddLayerInput">
#            키워드 검색
#           </label>
#           <div class="box__input">
#            <input class="form__input" id="vsSearchAddLayerInput" maxlength="100" name="vsSearchAddLayerQuery" placeholder="상품명을 입력하세요." spellcheck="false" type="text"/>
#            <button class="button__search" type="button">
#             <span class="blind">
#              검색
#             </span>
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="box__contents">
#        <div class="box__compare">
#         <div class="box__compare-tabpanel">
#          <div aria-labelledby="vsSearchAddLayerTabButton1" class="box__tabpanel" id="vsSearchAddLayerTabPanel1" role="tabpanel" style="display: block">
#           <ul class="list__products">
#           </ul>
#           <div class="box__more" style="display: none">
#            <button class="button__more" type="button">
#             <span class="text__more">
#              더보기
#             </span>
#            </button>
#           </div>
#          </div>
#          <div aria-labelledby="vsSearchAddLayerTabButton2" class="box__tabpanel" id="vsSearchAddLayerTabPanel2" role="tabpanel" style="display: none">
#           <ul class="list__products">
#           </ul>
#           <div class="box__more" style="display: none">
#            <button class="button__more" type="button">
#             <span class="text__more">
#              더보기
#             </span>
#            </button>
#           </div>
#          </div>
#          <div aria-labelledby="vsSearchAddLayerTabButton3" class="box__tabpanel" id="vsSearchAddLayerTabPanel3" role="tabpanel" style="display: none">
#           <div class="box__blank">
#            <div class="text__comment">
#             상품을 검색해주세요.
#            </div>
#           </div>
#           <ul class="list__products">
#           </ul>
#           <div class="box__more" style="display: none">
#            <button class="button__more" type="button">
#             <span class="text__more">
#              더보기
#             </span>
#            </button>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div class="box__bottom">
#        <button class="button__close" type="button">
#         <span class="text__close">
#          닫기
#         </span>
#        </button>
#       </div>
#       <button class="button__close" type="button">
#        <span class="blind">
#         닫기
#        </span>
#       </button>
#      </div>
#     </div>
#     <div class="top_down_position">
#      <div class="top_down_area">
#       <div class="top_down_fixed">
#        <a class="btn_layer_up" href="#">
#         <span>
#          컨텐츠 상단으로 이동
#         </span>
#        </a>
#        <a class="btn_layer_down" href="#">
#         <span>
#          컨텐츠 하단으로 이동
#         </span>
#        </a>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- //danawa_container -->
#   </div>
#   <div id="danawa_footer">
#    <div class="footer">
#     <div class="footer__top">
#      <div class="footer__inner">
#       <dl class="footer__notice">
#        <dt class="title">
#         공지
#        </dt>
#        <dd class="subj">
#         <a href="http://help.danawa.com/noticeDetail.php?listSeq=5507260" target="_blank">
#          다나와 사칭 사이트 주의 안내
#         </a>
#        </dd>
#       </dl>
#       <ul class="footer__menu">
#        <li class="item">
#         <a href="https://www.danawa.com/corp/main.html" target="_blank">
#          다나와 소개
#         </a>
#        </li>
#        <li class="item">
#         <a href="https://www.danawa.com/info/provision.html" target="_blank">
#          이용약관
#         </a>
#        </li>
#        <li class="item">
#         <a href="https://www.danawa.com/info/helprule_private.html" target="_blank">
#          개인정보처리방침
#         </a>
#        </li>
#        <li class="item">
#         <a href="https://www.danawa.com/info/boyspro.html" target="_blank">
#          청소년 보호정책
#         </a>
#        </li>
#        <li class="item">
#         <a href="https://www.danawa.com/info/map.html" target="_blank">
#          사이트맵
#         </a>
#        </li>
#        <li class="item">
#         <a href="https://adcenter.danawa.com" target="_blank">
#          광고센터
#         </a>
#        </li>
#        <li class="item">
#         <a href="https://help.danawa.com/bizCenter/index.php?depth1=1" target="_blank">
#          협력사문의
#         </a>
#        </li>
#       </ul>
#      </div>
#     </div>
#     <div class="footer__wrap">
#      <div class="footer__inner">
#       <div class="footer__info">
#        <div class="footer__about">
#         <span class="address">
#          주소 (우) 08510 서울특별시 금천구 벚꽃로 298, 17층(가산동, 대륭포스트타워6차)
#         </span>
#         <span class="txt">
#          대표: 이건수
#         </span>
#         <br/>
#         <span class="txt">
#          사업자번호: 117-81-40065
#         </span>
#         <span class="txt">
#          통신판매업: 제2004-서울양천-00918호
#         </span>
#         <span class="txt">
#          부가통신사업: 제003081호
#          <a class="btn_footer" href="https://www.ftc.go.kr/bizCommPop.do?wrkr_no=1178140065" target="_blank">
#           사업자정보확인
#          </a>
#         </span>
#        </div>
#        <div class="footer__law">
#         <strong class="title">
#          콘텐츠산업진흥법
#         </strong>
#         <span class="summary">
#          콘텐츠산업 진흥법에 의한 콘텐츠 보호
#         </span>
#         <a class="btn_footer" href="#" id="content_see_more" role="button">
#          자세히보기
#         </a>
#         <div aria-label="콘텐츠산업진흥법에 의한 표시" class="layer__basic" id="footer_law_layer" role="dialog">
#          <div class="layer__basic__wrap">
#           <div class="layer__basic__header">
#            <strong class="layer__basic__title">
#             콘텐츠산업진흥법에 의한 표시
#            </strong>
#           </div>
#           <div class="layer__basic__cont">
#            <div class="layer__footer-law">
#             <div class="layer__footer-law__detail">
#              <dl class="row">
#               <dt class="title">
#                콘텐츠의 명칭
#               </dt>
#               <dd class="cont">
#                상품콘텐츠(정보) 및 기사, 이벤트 정보
#               </dd>
#              </dl>
#              <dl class="row">
#               <dt class="title">
#                콘텐츠의 제작 및 표시 연월일
#               </dt>
#               <dd class="cont">
#                개별 표기된 제작일 또는 갱신일
#               </dd>
#              </dl>
#              <dl class="row">
#               <dt class="title">
#                콘텐츠의 제작자
#               </dt>
#               <dd class="cont">
#                (주)커넥트웨이브
#                <br/>
#                전화: 1688 - 2470 (유료) / 팩스: 1688-2451
#                <br/>
#                서울특별시 양천구 목동동로 233-1 드림타워 501호
#               </dd>
#              </dl>
#              <dl class="row">
#               <dt class="title">
#                콘텐츠의 이용조건
#               </dt>
#               <dd class="cont">
#                이용약관 및 서비스 안내 참조
#                <br/>
#                (동의 없이 무단복제 및 가공을 금함)
#                <a class="btn_footer" href="https://www.danawa.com/info/agreement.html" target="_blank">
#                 이용약관 보기
#                </a>
#               </dd>
#              </dl>
#             </div>
#             <div class="layer__footer-law__noti">
#              <p class="text">
#               (주)커넥트웨이브 홈페이지 내의 모든 콘텐츠는 『콘텐츠산업 진흥법』에 따라
#               <br/>
#               제작일 또는 그 갱신일로부터 5년간 보호 됩니다.
#              </p>
#             </div>
#            </div>
#           </div>
#           <button class="layer__basic__close" type="button">
#            <span class="blind">
#             닫기
#            </span>
#           </button>
#          </div>
#         </div>
#         <a class="btn_footer" href="https://help.danawa.com/bizCenter/index.php?depth1=11" target="_blank">
#          콘텐츠이용안내
#         </a>
#        </div>
#        <div class="footer__point">
#         (주)커넥트웨이브는 상품판매와 직접적인 관련이 없으며, 모든 상거래의 책임은 구매자와 판매자에게 있습니다.
#         <br/>
#         이에 대해 (주)커넥트웨이브는 일체의 책임을 지지 않습니다.
#         <br/>
#         본사에 등록된 모든 광고와 저작권 및 법적책임은 자료제공사 (또는 글쓴이)에게 있으므로 본사는 광고에 대한 책임을 지지 않습니다.
#        </div>
#        <address class="footer__copy">
#         Copyright ©
#         <strong>
#          connectwave
#         </strong>
#         Co., Ltd. All Rights Reserved.
#        </address>
#        <div class="footer__kolsa">
#         <a href="https://www.kolsa.or.kr" target="_blank">
#          <span class="blind">
#           KOLSA 한국온라인 쇼핑협회
#          </span>
#         </a>
#        </div>
#       </div>
#       <div class="footer__cs">
#        <strong class="title">
#         다나와 고객센터
#        </strong>
#        <div class="service">
#         <a class="link link--home" href="https://help.danawa.com" target="_blank">
#          고객센터 홈
#         </a>
#         <a class="link link--inquiry" href="#" onclick="window.open('https://help.danawa.com/onlineInquiry.php?referUrl='+ window.location.href,'_blank', 'width=800, height=900, toolbar=no, menubar=no, scrollbars=no, resizable=no, copyhistory=no'); return false;" target="_blank">
#          신고/문의/제안
#         </a>
#         <a class="link link--help" href="https://help.danawa.com/serviceHelpList.php" target="_blank">
#          서비스도움말
#         </a>
#        </div>
#        <ul class="info">
#         <li class="item">
#          전화: 1688-2470 (유료)
#         </li>
#         <li class="item">
#          팩스: 1688-2451
#         </li>
#         <li class="item">
#          이메일: cs@cowave.kr
#         </li>
#        </ul>
#        <ul class="relative">
#         <li class="item">
#          <a class="btn_footer" href="#" id="denyEmailOpenBtn" onclick="return false;" role="button">
#           이메일수집거부
#          </a>
#          <div aria-label="이메일 주소 무단 수신수집 거부" class="layer__basic" id="denyEmailNoticeArea" role="dialog">
#           <div class="layer__basic__wrap">
#            <div class="layer__basic__header">
#             <strong class="layer__basic__title">
#              이메일 주소 무단 수신수집 거부
#             </strong>
#            </div>
#            <div class="layer__basic__cont">
#             <div class="layer__footer-denyemail">
#              <p class="contents">
#               영리목적 (주)커넥트웨이브에서는 본 웹사이트에 게시된 이메일 주소가
#               <br/>
#               전자우편 수집 프로그램이나 그 밖의 기술적 장치를 이용하여
#               <br/>
#               무단으로 수집되는 것을 거부하며, 이를 위반시
#               <br/>
#               <strong class="point">
#                정보통신망법에 의해 형사처벌됨
#               </strong>
#               을 유념하시기 바랍니다.
#              </p>
#              <span class="date">
#               [게시일 2004년 1월 16일]
#              </span>
#             </div>
#            </div>
#            <button class="layer__basic__close" id="denyEmailCloseBtn" type="button">
#             <span class="blind">
#              닫기
#             </span>
#            </button>
#           </div>
#          </div>
#         </li>
#         <li class="item">
#          <a class="btn_footer" href="https://help.danawa.com/ars_suggestion.php" target="_blank">
#           ARS문의안내
#          </a>
#         </li>
#        </ul>
#       </div>
#      </div>
#     </div>
#     <script type="text/javascript">
#      var sProductListUrl = "https://prod.danawa.com/list";
# 		var oCategoryLnb = null;
# 		var oExplodeCategoryLnb = null;
# 		var sCategoryExplodeLoggerText = "main";
#
# 		//카테고리 LNB, 펼쳐보기 draw
# 		$(document).ready(function(){
# 			oCategoryLnb = new CategoryLnb();
# 			oCategoryLnb.setListRootUrl("https://prod.danawa.com/list/");
# 			oCategoryLnb.setRootElement($(".main-header__category .category_hover_layer_wrap"));
# 			oCategoryLnb.setSectionElement($(".main-header__category #sectionLayer"));
# 		});
#
# 		_TRK_PI = "Main";
#
# 		var memberId = ""
#     </script>
#     <script src="//static.danawa.com/globaljs/external/yall/yall.min.js">
#     </script>
#     <script src="//static.danawa.com/globaljs/external/yall/intersection-observer.js">
#     </script>
#     <script src="//static.danawa.com/globaljs/external/modernizr/2.8.3/modernizr.custom.touch-events.js?v=2405281337">
#     </script>
#     <script src="//static.danawa.com/globaljs/external/jquery/plugin/jquery.mousewheel/3.1.12/jquery.mousewheel.min.js?v=2405281337">
#     </script>
#     <script src="//static.danawa.com/globaljs/static/bdl/dsas_client.min.js?v=1.0.0">
#     </script>
#     <script src="//static.danawa.com/globaljs/com/danawa/util/common_lnb.js?v=2405281337">
#     </script>
#     <script src="//static.danawa.com/globaljs/com/danawa/common/category/mainLNBMenu.js?v=2405281337">
#     </script>
#     <script src="https://www.danawa.com/main/js/mainLayer.js?v=2405281337">
#     </script>
#     <script src="https://www.danawa.com/main/js/priceCompareTop100.js?v=2405281337">
#     </script>
#     <script src="//static.danawa.com/globaljs/com/danawa/common/category/main_lnb_ui.js?v=2405281337">
#     </script>
#     <script src="https://www.danawa.com/main/js/mainLogger.js?v=2405281337">
#     </script>
#     <script src="//static.danawa.com/globaljs/external/swiper/5.4.5/swiper.min.js?v=2405281337">
#     </script>
#     <script src="//static.danawa.com/globaljs/external/postscribe/postscribe.min.js">
#     </script>
#     <script>
#      var _TRK_CP = '메인_NEW/통합메인';
#     </script>
#    </div>
#   </div>
#   <script src="https://static.danawa.com/globaljs/static/logger_trackEvent.js">
#   </script>
#   <script src="https://static.danawa.com/globaljs/static/logger_Insight_WebAnalytics.js">
#   </script>
#   <script src="https://static.danawa.com/globaljs/static/wcslog.js?v1607061545=">
#   </script>
#   <script>
#    if (!wcs_add) var wcs_add = {};
# 			wcs_add["wa"] = "s_3b3fb74948b1";
# 			if (!_nasa) var _nasa = {};
# 			wcs.inflow("danawa.com");
# 			wcs_do(_nasa);
#   </script>
#   <script>
#    var _CZN = '1';
#   </script>
#   <script defer="" src="https://static.danawa.com/globaljs/static/InsightClickZone.js">
#   </script>
#   <style>
#    #t1Banner {
# 				width: 510px;
# 				height: 145px;
# 				position: absolute;
# 				left: 50%;
# 				top: 485px;
# 				margin: 0 0 0 -199px;
# 			}
#   </style>
#   <div id="t1Banner">
#    <script src="">
#    </script>
#    <script>
#     $('#t1Banner div[id^="adFloatLayer"]').css("z-index", 999);
#    </script>
#   </div>
#   <div id="mainDim">
#   </div>
#   <script type="application/ld+json">
#    {
# 			"@context": "https://schema.org",
# 			"@type": "Person",
# 			"name": "다나와",
# 			"url": "https://www.danawa.com",
# 			"sameAs": [
# 				"https://post.naver.com/my.naver?memberNo=639132",
# 				"https://www.facebook.com/danawastory",
# 				"https://play.google.com/store/apps/details?id=com.sktelecom.Danawa.Main&hl=ko",
# 				"https://itunes.apple.com/kr/app/%EB%8B%A4%EB%82%98%EC%99%80-%EA%B0%80%EA%B2%A9%EB%B9%84%EA%B5%90/id454345858?mt=8",
# 				"https://blog.naver.com/danawaelec",
# 				"https://cafe.naver.com/shopdanawa"
# 			]
# 		}
#   </script>
#   <!-- view as mobile script -->
#   <script src="https://static.danawa.com/globaljs/com/danawa/common/setUpMobileView.js">
#   </script>
#   <!-- Google Analytics 4(GA4) -->
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-L8D5P2KD8Z">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#
# 	function gtag() {
# 		dataLayer.push(arguments);
# 	}
# 	gtag('js', new Date());
# 	gtag('config', 'AW-963914956'); // 제휴캠페인
# 	gtag('config', 'AW-631507961'); // 확장캠페인
# 	gtag('config', 'AW-10932905353'); // 듀얼_기존
# 	gtag('config', 'AW-10933251710'); // 듀얼_확장
# 	gtag('config', 'G-L8D5P2KD8Z'); // GA4
#   </script>
#   <!-- Enliple Tracker Start -->
#   <script>
#    var ENP_VAR = {
# 			collect: {},
# 			conversion: {
# 				product: []
# 			}
# 		};
#
# 		(function(a, g, e, n, t) {
# 			a.enp = a.enp || function() {
# 				(a.enp.q = a.enp.q || []).push(arguments)
# 			};
# 			n = g.createElement(e);
# 			n.defer = !0;
# 			n.src = "https://cdn.megadata.co.kr/dist/prod/enp_tracker_self_hosted.min.js";
# 			t = g.getElementsByTagName(e)[0];
# 			t.parentNode.insertBefore(n, t)
# 		})(window, document, "script");
# 		enp('create', 'common', 'danawa', {
# 			device: 'W'
# 		});
# 		enp('send', 'common', 'danawa');
#   </script>
#   <!-- Enliple Tracker End -->
#  </body>
# </html>
# '\n파싱 : 변환되지 않을 수도 있는 것을 변환하는 행위\n-> 위험하다 / 예외처리가 필요(try-catch)\n'

# %%
# 구체적인 선택자를 사용하는 이유
# 1. 중복이 존재할 수 있어서
# 2. 가독성
# 3. 선택자가 구체적일 수록 동작이 더 빠르다.
navs = soup.select("#danawa_menubar>.main-header__nav> .link_nav")  # 복수의 요소(노드)를 찾는 것 -> list 반환

for nav in navs:
    print(f'{nav.text} / {nav.get("href")}')
# Out:
# 자동차 / https://auto.danawa.com/?logger_kw=dnw_gnb_auto
# 조립PC / https://shop.danawa.com/shopmain/?logger_kw=dnw_gnb_pcmain
# PC견적 / https://shop.danawa.com/virtualestimate/?controller=estimateMain&methods=index&marketPlaceSeq=16&logger_kw=dnw_gnb_esti
# PC구매상담 / https://pc26.danawa.com/bbs/?logger_kw=dnw_gnb_pc26
# 여행 / https://tour.danawa.com/?logger_kw=dnw_gnb_tour
# 쇼핑기획전 / https://plan.danawa.com/?logger_kw=dnw_gnb_plan
# 커뮤니티 / https://dpg.danawa.com/bbs?logger_kw=dnw_gnb_dpg
# 이벤트 / https://event.danawa.com/?logger_kw=dnw_gnb_event
# / / None
# 체험단 / https://event.danawa.com/experience/?logger_kw=dnw_gnb_experience

# %%
# 움직이는 메뉴의 선택자를 찾아서 출력하기
moveNavs = soup.select(".main-top100__nav> .main-top100__nav__anchor")
moveNavs
for nav in moveNavs:
    print(nav.text)
    print(nav.get("href"))  # get(속성): 해당 노드의 속성 값을 반환
    # href가 아이디를 참조하면 해당 아이디로 스크롤 이동한다
# Out:
# 전체
# #top100_0
# 가전TV
# #top100_10
# 컴퓨터노트북조립PC
# #top100_11
# 태블릿모바일디카
# #top100_12
# 골프스포츠
# #top100_13
# 자동차용품공구
# #top100_14
# 가구조명
# #top100_15
# 식품유아완구
# #top100_16
# 생활주방건강
# #top100_17
# 패션잡화뷰티
# #top100_18
# 반려동물취미사무
# #top100_19
