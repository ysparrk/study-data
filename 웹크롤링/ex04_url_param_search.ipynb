# %% [markdown]
# # 다나와 검색
# - 파라미터
# - https://search.danawa.com/dsearch.php?query=lg+notebook
# - dsearch.php : path 인 리소스
#     - php리소스는 서버에서 동작 후 결과를 반환하는 동적 페이지 -> 동작하기 위한 파라미터가 필요
# - dsearch.html : 서버에서 바로 반환하는 정적 페이지
# - lg notebook => lg+notebook (url encoding, url에서 띄어쓰기를 +로 표현)
#
#
# * 참고
# - php : 서버 사이드 스트립트 언어
# - 스크립트 언어 : 문자열 그대로 실행되는 프로그래밍 언어

# %%
import requests as req
from bs4 import BeautifulSoup as bs

query = input("무엇을 검색하시겠습니까?")
url = f"https://search.danawa.com/dsearch.php?query={query}"
headers = {'User-Agent': 'Mozilla/5.0'}
res = req.get(url=url, headers=headers)
soup = bs(res.text, "html.parser")
# print(soup.prettify())

# %%
items = soup.select(".prod_main_info")

for item in items:
    # title
    titleNode = item.select_one(".click_log_product_standard_title_")  # select_one -> 첫번째 결과 하나 반환
    title = titleNode.text if titleNode != None else "타이틀 없음"

    # price
    priceNode = item.select_one(".rank_one>.price_sect>.click_log_product_standard_price_")
    price = priceNode.text if priceNode != None else 0
    
    price = price.replace(",", "")
    price = price.replace("원", "")
    price_int = int(price)
    
    # point
    pointNode = item.select_one(".point_num")
    point = pointNode.text if pointNode != None else "리뷰없음"

    print(f'{title} / {price}원 / {point}')
# Out:
# APPLE 아이폰15 128GB, SKT 완납 / 329800원 / 리뷰없음
# APPLE 아이폰15 256GB, KT 완납 / 527600원 /
# 5.0점
#
# APPLE 아이폰15 128GB, KT 완납 / 276800원 /
# 5.0점
#
# APPLE 아이폰15 128GB, 공기계 / 779000원 / 리뷰없음
# APPLE 아이폰15 256GB, SKT 완납 / 500900원 / 리뷰없음
# APPLE 아이폰15 256GB, LG U+ 완납 / 627870원 / 리뷰없음
# APPLE 아이폰15 512GB, KT 완납 / 874000원 / 리뷰없음
# APPLE 아이폰15 128GB, SKT 제휴카드 / 19900원 /
# 5.0점
#
# APPLE 아이폰15 128GB, 자급제 / 1105600원 /
# 4.8점
#
# APPLE 아이폰15 256GB, SKT 제휴카드 / 19900원 / 리뷰없음
# APPLE 아이폰15 128GB, LG U+ 완납 / 302900원 / 리뷰없음
# APPLE 아이폰15 128GB, LG U+ 제휴카드 / 31890원 / 리뷰없음
# APPLE 아이폰15 256GB, KT 제휴카드 / 287890원 / 리뷰없음
# APPLE 아이폰15 512GB, SKT 완납 / 982900원 / 리뷰없음
# APPLE 아이폰15 256GB, LG U+ 제휴카드 / 567930원 / 리뷰없음
# APPLE 아이폰15 128GB, KT 제휴카드 / 509980원 / 리뷰없음
# APPLE 아이폰15 512GB, LG U+ 제휴카드 / 1123970원 / 리뷰없음
# APPLE 아이폰15 512GB, LG U+ 완납 / 1176500원 / 리뷰없음
# APPLE 아이폰15 256GB, 자급제 / 1259000원 /
# 4.8점
#
# APPLE 아이폰15 512GB, 자급제 / 1619190원 /
# 4.9점
#
# APPLE 아이폰15 256GB, 공기계 / 839000원 /
# 4.0점
#
# APPLE 아이폰15 512GB, SKT 제휴카드 / 225990원 / 리뷰없음
# APPLE 아이폰15 512GB, KT 제휴카드 / 781990원 / 리뷰없음
# APPLE 아이폰15 512GB, 공기계 / 299000원 / 리뷰없음
# APPLE 아이폰15 프로 256GB, 자급제 / 1527000원 /
# 4.9점
#
# APPLE 아이폰15 프로 맥스 256GB, 자급제 / 1715900원 /
# 4.9점
#
# APPLE 아이폰15 프로 128GB, 자급제 / 1407990원 /
# 4.9점
#
# APPLE 아이폰15 플러스 128GB, 자급제 / 1120500원 /
# 4.9점
#
# APPLE 아이폰15 프로 맥스 512GB, 자급제 / 1991000원 /
# 4.9점
#
# APPLE 아이폰15 프로 512GB, 자급제 / 1839890원 /
# 4.9점
#
# APPLE 아이폰14 프로 512GB, 자급제 / 1641990원 /
# 4.8점
#
# APPLE 아이폰13 미니 128GB, 자급제 / 758990원 /
# 4.8점
#
# APPLE 아이폰15 프로 맥스 1TB, 자급제 / 2274990원 /
# 4.9점
#
# APPLE 아이폰15 플러스 256GB, 자급제 / 1245000원 /
# 4.8점
#
# APPLE 아이폰15 프로 256GB, SKT 완납 / 814600원 / 리뷰없음
# APPLE 아이폰15 프로 128GB, SKT 완납 / 643500원 / 리뷰없음
# APPLE 아이폰12 미니 64GB, 공기계 / 202420원 /
# 4.8점
#
# APPLE 아이폰12 미니 128GB, 공기계 / 239440원 /
# 5.0점
#
# APPLE 아이폰14 128GB, 자급제 / 945990원 /
# 4.8점
#
# APPLE 아이폰15 프로 1TB, 자급제 / 2140370원 /
# 4.8점
